# %% [markdown]
# # Лекция 2:  Web
#
# ## Intro
#
# ### Работа с HTTP-запросами
# - библиотека `requests` (recommended)
# - библиотека `urllib`
# - библиотека `bs4.BeautifulSoup` (recommended)
# - библиотека `lxml`
# - библиотека `scrapy`

# %% [markdown]
# #### `requests`  &  `urllib.request`
#
# ```python
# import requests
# ```
#
# Маркером того, что страница существует и успешно загрузилась, является _Response [200]_
# ```python
# url = 'https://www.hse.ru'
# requests.get(url)
#
# > <Response [200]>
# ```
#
# То же самое с `urllib.request`:
# ```python
# import urllib
# urllibreq = urllib.request.urlopen(url)
# print(urllibreq.getcode())
#
# > 200
# ```

# %% [markdown]
# Посмотреть все методы того класса, к которому принадлежит ваш объект, можно несколькими способами:
#  1. открыв документацию
#  2. открыв непосредственно код класса
#  3. либо прям в коде с помощью метода _dir(  )_

# %%
url = 'https://www.hse.ru'
req = requests.get(url)

dir(req)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
print(req.encoding)
print(req.url)
print(req.status_code)
# Out:
# utf-8
# https://www.hse.ru/en/
# 200

# %%
# пример чтения страницы с requests
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n\n\n\n\n\n\n\n\n\n<head>\n\t<title>National Research University Higher School of Economics</title>\n\t<meta charset="utf-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta name="yandex-verification" content="25e3420f8bfc397e" />\n\t<meta name="theme-color" content="#1658DA"/>\n\t<meta name="sputnik-verification" content="SB2V6wrEtxYZNqgs" />\n\t<link rel="manifest" href="https://www.hse.ru/f/src/manifest/manifest_en.json">\n\t\n\t\t<link href="//www.hse.ru/en/" rel="canonical">\n\t\n\t<link rel="stylesheet" href="/f/src/global/css/main_fonts.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/main_icons.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/main_forms.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/fotorama.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/sitemap.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/main_hse.css" />\n\t<link rel="stylesheet" href="/f/src/home/main_en.css" />\n\t<link rel="stylesheet" href="/f/src/home/owl.carousel.css" />\n\t<link rel="stylesheet" href="/f/src/global/css/vision.css" />\n\t<!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->\n\t<script type="text/javascript" src="/f/src/global/js/cache/jquery-1.10.1.min/jquery.cookie/hse.utils/main/ctrlshifte/popup/fotorama/owl.carousel.min/home_en/edu_mobile/modernizr/sitemap.ajax/android/vision/sw-register.js"></script>\n\t<script type="text/javascript" src="/f/src/global/bower_components/jquery-ui/ui/effect.js"></script>\n\t<script type="text/javascript" src="/f/src/global/bower_components/moment/min/moment-with-locales.min.js"></script>\n\t<script type="text/javascript" src="/f/src/global/bower_components/jquery-bigtext/jquery-bigtext.js"></script>\n\t<script type="text/javascript">\n\t\t(function() {\n\t\t\tvar s = document.createElement(\'script\');\n\t\t\ts.type = \'text/javascript\'; s.async = true;\n\t\t\ts.src = \'/f/src/_/jquery.orfo.js\';\n\t\t\ts.onload = s.onreadystatechange = function() {\n\t\t\t\tif ($.fn.hseOrfo) {\t// old IE...\n\t\t\t\t\t$(document).hseOrfo({\n\t\t\t\t\t\t\'lang\': \'en\'\n\t\t\t\t\t});\n\t\t\t\t}\n\t\t\t};\n\t\t\tvar t = document.getElementsByTagName(\'script\')[0]; t.parentNode.insertBefore(s, t);\n\t\t})();\n\t</script>\n\t\n\t<meta name="twitter:card" content="summary"><meta property="og:title" content="National Research University Higher School of Economics">\t\t\n\t<meta name="mrc__share_title" content="National Research University Higher School of Economics">\n\t<meta itemprop="name" content="National Research University Higher School of Economics"><meta property="og:description" content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences">\n\t<meta name="mrc__share_description" content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences">\n\t<meta itemprop="description" content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences">\n\t<meta name="twitter:description" content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences"><meta property="og:image" content="https://www.hse.ru/images/fb/hse_en_thumb.jpg">\n\t<meta itemprop="image" content="https://www.hse.ru/images/fb/hse_en_thumb.jpg">\n\t<link rel="image_src" href="https://www.hse.ru/images/fb/hse_en_thumb.jpg"><meta name="twitter:image" content=""><meta property="og:url" content="//www.hse.ru/en/"><meta name="twitter:url" content="//www.hse.ru/en/"><meta property="og:type" content="website">\n\n\t<style>\n\t\t\n\t\t\t\n\t\t\t\t.main_slider__item.interstud {background-position: 50% 30%;}\n\t\t\t\n\t\t\n\t\t\t\n\t\t\t\t.main_slider ...

# %% [markdown]
# Я рекомендую работать с _requests_. Она не так нагружена как _urllib_, при этом удовлетворяет всему, что вам  может быть необходимо для парсинга сайтов, ведь по сути она является оберткой над urllib3.
# Для понимания, вот пример одного и того же вывода для двух этих библиотек.
#
# ![](pics/urllib_req.png)

# %% [markdown]
# ### BeautifulSoup  &  lxml

# %%
from bs4 import BeautifulSoup

# %%
# скачиваем страницу
url = 'https://www.hse.ru'
req = requests.get(url)
html = req.text

# %%
# к тексту страницы применяем BeautifulSoup
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>National Research University Higher School of Economics</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="25e3420f8bfc397e" name="yandex-verification"/>
# <meta content="#1658DA" name="theme-color"/>
# <meta content="SB2V6wrEtxYZNqgs" name="sputnik-verification"/>
# <link href="https://www.hse.ru/f/src/manifest/manifest_en.json" rel="manifest"/>
# <link href="//www.hse.ru/en/" rel="canonical"/>
# <link href="/f/src/global/css/main_fonts.css" rel="stylesheet"/>
# <link href="/f/src/global/css/main_icons.css" rel="stylesheet"/>
# <link href="/f/src/global/css/main_forms.css" rel="stylesheet"/>
# <link href="/f/src/global/css/fotorama.css" rel="stylesheet"/>
# <link href="/f/src/global/css/sitemap.css" rel="stylesheet"/>
# <link href="/f/src/global/css/main_hse.css" rel="stylesheet"/>
# <link href="/f/src/home/main_en.css" rel="stylesheet"/>
# <link href="/f/src/home/owl.carousel.css" rel="stylesheet"/>
# <link href="/f/src/global/css/vision.css" rel="stylesheet"/>
# <!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->
# <script src="/f/src/global/js/cache/jquery-1.10.1.min/jquery.cookie/hse.utils/main/ctrlshifte/popup/fotorama/owl.carousel.min/home_en/edu_mobile/modernizr/sitemap.ajax/android/vision/sw-register.js" type="text/javascript"></script>
# <script src="/f/src/global/bower_components/jquery-ui/ui/effect.js" type="text/javascript"></script>
# <script src="/f/src/global/bower_components/moment/min/moment-with-locales.min.js" type="text/javascript"></script>
# <script src="/f/src/global/bower_components/jquery-bigtext/jquery-bigtext.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		(function() {
# 			var s = document.createElement('script');
# 			s.type = 'text/javascript'; s.async = true;
# 			s.src = '/f/src/_/jquery.orfo.js';
# 			s.onload = s.onreadystatechange = function() {
# 				if ($.fn.hseOrfo) {	// old IE...
# 					$(document).hseOrfo({
# 						'lang': 'en'
# 					});
# 				}
# 			};
# 			var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(s, t);
# 		})();
# 	</script>
# <meta content="summary" name="twitter:card"/><meta content="National Research University Higher School of Economics" property="og:title"/>
# <meta content="National Research University Higher School of Economics" name="mrc__share_title"/>
# <meta content="National Research University Higher School of Economics" itemprop="name"/><meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" property="og:description"/>
# <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" name="mrc__share_description"/>
# <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" itemprop="description"/>
# <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" name="twitter:description"/><meta content="https://www.hse.ru/images/fb/hse_en_thumb.jpg" property="og:image"/>
# <meta content="https://www.hse.ru/images/fb/hse_en_thumb.jpg" itemprop="image"/>
# <link href="https://www.hse.ru/images/fb/hse_en_thumb.jpg" rel="image_src"/><meta content="" name="twitter:image"/><meta content="//www.hse.ru/en/" property="og:url"/><meta content="//www.hse.ru/en/" name="twitter:url"/><meta content="website" property="og:type"/>
# <style>
#
#
# 				.main_slider__item.interstud {background-position: 50% 30%;}
#
#
#
# 				.main_slider__item.niwork {background-position: 50% 20%;}
#
#
#
# 				.day18.main_slider__item {background-position: 50% 50%;}
# @media screen and (max-width: 768px) {
# 	.day18 .day18_logo {display: none;}
# }
# @media screen and (min-width: 769px) {
# 	.day18 h3 {display: none;}
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			.section--abitur .section_title, .section_title--abitur, .c-abitur {
# 				color: #2c8fc0;
# 			}
#
# 			.section--abitur .owl-prev { border-left-color: #2c8fc0; border-bottom-color: #2c8fc0; }
# 			.section--abitur .owl-next { border-right-color: #2c8fc0; border-bottom-color: #2c8fc0;}
# 			.section--abitur .owl-pagination::after {
# 				background-image: linear-gradient(to right, #2c8fc0, rgba(202,228,146,.2));
# 			}
#
# 			.section--abitur .owl-pagination::before {
# 				background-image: linear-gradient(to left, #2c8fc0, rgba(202,228,146,.2));
# 			}
#
# 			.section--abitur  .owl-page span {
# 				background: #2c8fc0;
# 			}
#
# 			.section--abitur  .owl-page.active span {
# 				border-color: #2c8fc0;
# 			}
#
#
# 	</style>
# <script type="text/javascript"><!--
# (function (d, w, c) {
# 							(w[c] = w[c] || []).push(function() {
# 											try {
# 															w.yaCounter32635220 = new Ya.Metrika({
# 																			id:32635220,
# 																			clickmap:true,
# 																			trackLinks:true,
# 																			accurateTrackBounce:true
# 															});
#
# 															w.yaCounter36283385 = new Ya.Metrika({
# 																			id:36283385,
# 																			clickmap:true,
# 																			trackLinks:true,
# 																			accurateTrackBounce:true,
# 																			trackHash:true,
# 																			webvisor:true
# 															});
# 											} catch(e) { }
# 							});
#
# 							var n = d.getElementsByTagName("script")[0],
# 											s = d.createElement("script"),
# 											f = function () { n.parentNode.insertBefore(s, n); };
# 							s.type = "text/javascript";
# 							s.async = true;
# 							s.src = "https://mc.yandex.ru/metrika/watch.js";
#
# 							if (w.opera == "[object Opera]") {
# 											d.addEventListener("DOMContentLoaded", f, false);
# 							} else { f(); }
# 			})(document, window, "yandex_metrika_callbacks");
#  var _gaq = _gaq || [];
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P6DCQX');
# //-->
# </script>
# </head>
# <body data-lang="en">
# <div class="page">
# <!--noindex-->
# <div class="browser_outdate" style="display:none;">
# 		В старых версиях браузеров сайт может отображаться некорректно. Для оптимальной работы с сайтом рекомендуем воспользоваться современным браузером.
# 	</div>
# <div class="gdpr_bar" style="display:none;">
# <div class="gdpr_bar__inner">
# <p>We use cookies in order to improve the quality and usability of the HSE website. More information about the use of cookies is available <a href="https://www.hse.ru/en/cookie.html">here</a>, and the regulations on processing personal data can be found <a href="https://www.hse.ru/en/data_protection_regulation">here</a>. By continuing to use the site, you hereby confirm that you have been informed of the use of cookies by the HSE website and agree with our rules for processing personal data. You may disable cookies in your browser settings.</p>
# <span class="gdpr_bar__close">✖</span>
# </div>
# </div>
# <!--/noindex-->
# <div class="sv-control">
# <div class="sv-control__block">
# <ul class="sv-control__list sv-size">
# <li class="sv-control__item sv-control__item--s_normal active" data-type="size" data-value="normal">A</li>
# <li class="sv-control__item sv-control__item--s_medium" data-type="size" data-value="medium">A</li>
# <li class="sv-control__item sv-control__item--s_large" data-type="size" data-value="large">A</li>
# </ul>
# </div>
# <div class="sv-control__block">
# <ul class="sv-control__list sv-spacing">
# <li class="active sv-control__item sv-control__item--ls_normal" data-type="spacing" data-value="normal">ABC</li>
# <li class="sv-control__item sv-control__item--ls_medium" data-type="spacing" data-value="medium">ABC</li>
# <li class="sv-control__item sv-control__item--ls_large" data-type="spacing" data-value="large">ABC</li>
# </ul>
# </div>
# <div class="sv-control__block">
# <ul class="sv-control__list sv-contrast">
# <li class="sv-control__item sv-control__item---color1 active" data-type="contrast" data-value="normal">А</li>
# <li class="sv-control__item sv-control__item---color2" data-type="contrast" data-value="invert">А</li>
# <li class="sv-control__item sv-control__item---color3" data-type="contrast" data-value="blue">А</li>
# <li class="sv-control__item sv-control__item---color4" data-type="contrast" data-value="beige">А</li>
# <li class="sv-control__item sv-control__item---color5" data-type="contrast" data-value="brown">А</li>
# </ul>
# </div>
# <div class="sv-control__block">
# <ul class="sv-control__list sv-image">
# <li class="sv-control__item sv-control__item--image_on active" data-type="image" data-value="on"></li>
# <li class="sv-control__item sv-control__item--image_off" data-type="image" data-value="off"></li>
# </ul>
# </div>
# <div class="sv-control__block">
# <div class="sv-off js-sv-off">
# 					Regular version of the site
# 				</div>
# </div>
# </div>
# <div class="layout">
# <div class="header-top">
# <div class="left is-desktop">
# <span class="control control_sitemap control_hidden">
# <span class="control_sitemap__line"></span>
# </span>
# </div>
# <div class="right">
# <div class="header__controls">
# <span class="control control_wider control_campus is-mobile">
# <span class="popup_opener campus with-icon with-icon_right with-icon_sortdown">Campus:
# 								<ins class="campus__emblem campus__emblem--msk"></ins>
# <span class="campus__name">Moscow</span>
# </span>
# <div class="popup popup_campus-select popup_campus-relative not_display">
# <ul class="navigation smaller">
# <li><a class="link no-visited with-icon with-icon_flag-nn" href="http://nnov.hse.ru/en/">Nizhny Novgorod</a></li>
# <li><a class="link no-visited with-icon with-icon_flag-spb" href="http://spb.hse.ru/en/">Saint Petersburg</a></li>
# <li><a class="link no-visited with-icon with-icon_flag-perm" href="http://perm.hse.ru/en/">Perm</a></li>
# </ul>
# </div>
# </span>
# <span class="campus_list is-desktop">
# <span class="campus">Campus:
#
#
# 						<ins class="campus__emblem campus__emblem--msk"></ins>
# <span class="campus__name">Moscow</span>
# </span>
# <a class="campus_list__item link_no-underline link no-visited" href="http://nnov.hse.ru/en/">Nizhny Novgorod</a>
# <a class="campus_list__item link_no-underline link no-visited" href="http://spb.hse.ru/en/">Saint Petersburg</a>
# <a class="campus_list__item link_no-underline link no-visited" href="http://perm.hse.ru/en/">Perm</a>
# </span>
# <span class="control control_wider is-desktop"><a class="m-link_white" href="//www.hse.ru/cn">中文版</a></span>
# <ul class="control_lang2 is-desktop">
# <li class="control_lang2_item first_child">
# <a class="link link_no-visited link_no-underline" href="//www.hse.ru/">RU</a>
# </li><li class="control_lang2_item activated last_child">
# <a class="link link_no-visited link_no-underline" href="//www.hse.ru/en/">EN</a>
# </li>
# </ul>
# <span class="control control_vision is-desktop" title="For visually-impaired">
# <svg height="12" viewbox="0 0 21 12" width="21" xmlns="http://www.w3.org/2000/svg"><title>vision</title><path d="M10.5 0c3.438 0 6.937 2.016 10.5 6.047-.844.844-1.383 1.375-1.617 1.594-.234.219-.805.703-1.711 1.453-.906.75-1.641 1.266-2.203 1.547-.563.281-1.305.578-2.227.891-.922.313-1.836.469-2.742.469-1.125 0-2.156-.141-3.094-.422-.938-.281-1.875-.766-2.813-1.453-.938-.688-1.672-1.273-2.203-1.758-.531-.484-1.328-1.273-2.391-2.367 2.031-2.031 3.836-3.539 5.414-4.523 1.578-.984 3.273-1.477 5.086-1.477zm0 10.266c1.156 0 2.148-.422 2.977-1.266.828-.844 1.242-1.844 1.242-3s-.414-2.156-1.242-3c-.828-.844-1.82-1.266-2.977-1.266-1.156 0-2.148.422-2.977 1.266-.828.844-1.242 1.844-1.242 3s.414 2.156 1.242 3c.828.844 1.82 1.266 2.977 1.266zm0-5.766c0 .438.141.797.422 1.078s.641.422 1.078.422c.313 0 .625-.109.938-.328v.328c0 .688-.234 1.273-.703 1.758-.469.484-1.047.727-1.734.727-.688 0-1.266-.242-1.734-.727-.469-.484-.703-1.07-.703-1.758s.234-1.273.703-1.758c.469-.484 1.047-.727 1.734-.727h.375c-.25.313-.375.641-.375.984z" fill="#1658DA"></path></svg>
# </span>
# <a class="control control_user is-desktop" href="https://www.hse.ru/en/user/" title="User profile (HSE staff only)"><ins><svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg"><title>user</title><path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA"></path></svg></ins></a>
# <span class="control control_search is-desktop" title="Search">
# <ins class="popup_opener"><svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg"><title>search</title><path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA"></path></svg></ins>
# <div class="popup popup_search popup_campus-relative not_display">
# <div class="popup__inner">
# <div class="search-form">
# <form action="//www.hse.ru/en/search/index.html">
# <div class="search-form__button">
# <button class="button button_grey">Search</button>
# </div>
# <div class="search-form__input">
# <input class="input input100 input_mr" name="text" placeholder="Looking for..." type="text"/>
# <input name="simple" type="hidden" value="1"/>
# <input name="searchid" type="hidden" value="2284688"/>
# </div>
# </form>
# </div>
# <div class="popup_search__text">
# <a class="link link_dark no-visited" href="//www.hse.ru/en/search/search.html?simple=0&amp;searchid=2284688">
# 										Advanced search
# 									</a><span class="b-adv-search"></span>
# </div>
# </div>
# </div>
# </span>
# <span class="control is-mobile control_menu js-control_menu_open" onclick="void(0)"><ins></ins></span>
# </div>
# </div>
# <div class="header__body">
# <ul class="navigation navigation--social" style="visibility:hidden;">
# <li class="navigation__item">
# <a class="external with-icon with-icon_fb-blue link" href="https://www.facebook.com/HSE.english" target="_blank" title="Facebook">
# <span class="navigation__title">Facebook </span>
# </a>
# </li>
# <li class="navigation__item">
# <a class="external with-icon with-icon_tw-blue link" href="https://twitter.com/HSE_eng" target="_blank" title="Twitter">
# <span class="navigation__title">Twitter </span>
# </a>
# </li>
# <li class="navigation__item">
# <a class="external with-icon with-icon_inst-blue link" href="https://www.instagram.com/hse_university/" target="_blank" title="Instagram">
# <span class="navigation__title">Instagram </span>
# </a>
# </li>
# <li class="navigation__item">
# <a class="external with-icon with-icon_in-blue link" href="https://www.linkedin.com/edu/school?id=17073" rel="nofollow" target="_blank" title="LinkedIn">
# <span class="navigation__title">LinkedIn </span>
# </a>
# </li>
# <li class="navigation__item">
# <a class="external with-icon with-icon_yt-blue link" href="https://www.youtube.com/playlist?list=PL-U1Z5tJ1i-YhBCL9qUCaTf9cN8TF67VR" rel="nofollow" target="_blank" title="YouTube">
# <span class="navigation__title">YouTube </span>
# </a>
# </li>
# <li class="navigation__item js-more">
# <span class="with-icon with-icon_dots-blue js-social_popup_control link"></span>
# <ul class="navigation popup navigation--social_popup js-social_popup"><li></li></ul>
# </li>
# </ul>
# </div>
# </div>
# <header class="header clear">
# <ul class="navigation navigation--target header__nav">
# <li class="navigation__item c-navy"><a href="#news">News</a></li>
# <li class="navigation__item c-abitur" style="color:#2c8fc0"><a href="#abitur">Admissions</a></li>
# <li class="navigation__item c-olive_dark"><a href="#events">Events</a></li>
# <li class="navigation__item c-orange"><a href="#around_hse">Around HSE</a></li>
# <li class="navigation__item c-gray"><a href="#contacts">Contacts</a></li>
# <li class="navigation__item c-navy"><a href="#sitemap">Sitemap</a></li>
# </ul>
# <div class="logo">
# <img alt="" class="logo__img" src="/images/main_en/hse_en_logo.svg"/>
# <div class="logo__box">
# <h1 class="logo__title">Higher School of Economics</h1>
# <span class="logo__subtitle">National Research University</span>
# </div>
# </div>
# <div class="header__content is-desktop">
# <div class="header__link">
# <ul class="navigation js-mobile_menu_content navigation--tight">
# <li class="navigation__item"><a href="http://www.hse.ru/en/education/faculty/">Faculties and Institutes</a></li>
# <li class="navigation__item"><a href="http://www.hse.ru/en/org/persons/">Faculty &amp; Staff</a></li>
# <li class="navigation__item"><a href="http://www.hse.ru/intpartners">International Partnerships</a></li>
# <li class="navigation__item"><a href="https://iri.hse.ru/">Academic Jobs</a></li>
# <li class="navigation__item"><a href="http://alumni.hse.ru/en/">Alumni</a></li>
# </ul>
# </div>
# <div class="header__important">
# <a class="header__important_in js-mobile_menu_content link_no-underline" href="https://www.hse.ru/en/our/">
# <span class="important">University Life</span>
# <p class="c-gray">Information for students &amp; faculty</p>
# </a>
# </div>
# </div>
# </header>
# <div class="js-mobile_popup fa-sidebar">
# <div class="header-board__top fa-sidebar__top--secondary js-mobile_popup__top is-fixed is-mobile">
# <div class="header-top fa-sidebar__top--secondary">
# <div class="left">
# <span class="control control_wider"><a href="//www.hse.ru/cn">中文版</a></span>
# <ul class="control_lang2">
# <li class="control_lang2_item first_child">
# <a class="link link_no-visited link_no-underline" href="//www.hse.ru/">RU</a>
# </li><li class="control_lang2_item activated last_child">
# <a class="link link_no-visited link_no-underline" href="//www.hse.ru/en/">EN</a>
# </li>
# </ul>
# <a class="control control_user control_white" href="https://www.hse.ru/en/user/" title="User profile (HSE staff only)"><ins><svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg"><title>user</title><path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA"></path></svg></ins></a>
# <span class="control control_white control_search js-search_mobile_control" title="Search"><ins><svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg"><title>search</title><path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA"></path></svg></ins></span>
# </div>
# <div class="right">
# <div class="header__controls">
# <span class="control is-mobile control_menu control_menu--close js-control_menu_close" onclick="void(0)"><ins></ins></span>
# </div>
# </div>
# </div>
# <div class="js-search_mobile_popup not_display is-mobile">
# <div class="search-form">
# <form action="//www.hse.ru/en/search/index.html">
# <div class="search-form__button">
# <button class="button button_grey ">Search</button>
# </div>
# <div class="search-form__input">
# <input class="input fa-search_input input100 input_mr" name="text" placeholder="Looking for..." type="text"/>
# <input name="simple" type="hidden" value="1"/>
# <input name="searchid" type="hidden" value="2284688"/>
# </div>
# </form>
# </div>
# <div class="popup__block">
# <a class="link_white" href="//www.hse.ru/en/search/search.html?simple=0&amp;searchid=2284688">Advanced search</a>
# </div>
# </div>
# <div class="header-board__title">
# <a class="link_white link_no-underline" href="//www.hse.ru/en/">
# <div class="logo__title">Higher School of Economics</div>
# <span class="logo__subtitle">National Research University</span>
# </a>
# </div>
# </div>
# <div class="js-mobile_popup__inner fa-sidemenu--primary">
# <div class="js-mobile_menu_content_wrap">
# <ul class="main_menu">
# <li class="js-dropdown main_menu__item main_menu__item--red"><a class="js-dropdown_link" href="https://www.hse.ru/en/info/">About</a>
# <i class="fa-sidemenu__arr"></i>
# <div class="main_menu__sub js-dropdown__sub">
# <ul class="main_menu__sublist">
# <li class="main_menu__subitem"><a href="http://www.hse.ru/en/figures/">Facts and Figures</a></li>
# <li class="main_menu__subitem"><a href="https://strategy.hse.ru/en/rating/">HSE in Rankings</a></li>
# <li class="main_menu__subitem"><a href="http://strategy.hse.ru/en/">Development Strategy</a></li>
# <li class="main_menu__subitem"><a href="https://www.hse.ru/en/buildinghse/">HSE Buildings</a></li>
# </ul>
# </div>
# </li>
# <li class="js-dropdown main_menu__item main_menu__item--brown"><a class="js-dropdown_link" href="http://www.hse.ru/en/education/">Programmes &amp; Courses</a>
# </li>
# <li class="js-dropdown main_menu__item main_menu__item--green"><a class="js-dropdown_link" href="http://www.hse.ru/admissions">Admissions</a>
# <i class="fa-sidemenu__arr"></i>
# <div class="main_menu__sub js-dropdown__sub">
# <ul class="main_menu__sublist">
# <li class="main_menu__subitem"><a href="https://www.hse.ru/admissions/preparatory-apply">Preparatory​ Year</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/undergraduate-apply">Undergraduate Programmes</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/graduate-apply">Graduate Programmes</a></li>
# <li class="main_menu__subitem"><a href="http://aspirantura.hse.ru/en/">Doctoral​ Programmes</a></li>
# <li class="main_menu__subitem main_menu__subitem--subheader">Short-term programmes</li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/international/summer/">Summer University</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/international/semester">Semester in Moscow</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/doingbusiness">Doing Business in Russia - Internship</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/exchange-apply">Exchange Programmes</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/en/rfl/">Russian Language Training</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/en/sumschool">Summer Schools</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/en/winter/">Winter Schools</a></li>
# </ul>
# </div>
# </li>
# <li class="js-dropdown main_menu__item main_menu__item--violet"><a class="js-dropdown_link" href="http://www.hse.ru/en/science/">Research</a>
# <i class="fa-sidemenu__arr"></i>
# <div class="main_menu__sub js-dropdown__sub">
# <ul class="main_menu__sublist">
# <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/about1/">About research at HSE</a></li>
# <li class="main_menu__subitem"><a href="http://www.hse.ru/interlabs/">International Laboratories</a></li>
# <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/conferences/">Conferences</a></li>
# <li class="main_menu__subitem"><a href="http://publications.hse.ru/en/">Publications</a></li>
# <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/review/">HSE University Review</a></li>
# <li class="main_menu__subitem main_menu__subitem--important">
# <a class="simple_btn" href="http://iq.hse.ru/en/">IQ.hse.ru</a>
# <span class="is-block"><a class="link link--important" href="http://iq.hse.ru/en/">Research-based analysis by HSE experts</a></span>
# </li>
# </ul>
# </div>
# </li>
# <li class="js-dropdown main_menu__item main_menu__item--yellow"><a class="js-dropdown_link" href="https://istudents.hse.ru/">International Support</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="main_slider fotorama" data-autoplay="4000" data-click="false" data-height="400px" data-loop="true" data-transitionduration="750" data-width="100%">
# <div class="main_slider__item interstud" style="background-image: url('//www.hse.ru/pubs/share/direct/201347995');">
# <h3 class="main_slider__title">
# <a href="https://www.hse.ru/en/news/admission/222430207.html">
# 								International Youth Olympiad for Prospective Students
# 							</a>
# </h3>
# <div class="main_slider__descr">
# <p>Your chance to win a full-tuition scholarship for HSE's undergraduate programmes</p>
# </div>
# </div>
# <div class="main_slider__item niwork" style="background-image: url('//www.hse.ru/pubs/share/direct/222901503');">
# <h3 class="main_slider__title">
# <a href="https://www.hse.ru/en/news/research/222825675.html">
# 								Student Research Paper Competition: Open to Everyone
# 							</a>
# </h3>
# <div class="main_slider__descr">
# <p>Deadline: October 15, 2018</p>
# </div>
# </div>
# <div class="main_slider__item day18" style="background-image: url('//www.hse.ru/pubs/share/direct/222562510');">
# <h3 class="main_slider__title">
# <a href="https://www.hse.ru/en/day2018/">
# 								HSE Day in Gorky park
# 							</a>
# </h3>
# <div class="main_slider__descr">
# <p class="day18_logo c"><a class="link_no-underline" href="https://www.hse.ru/en/day2018/"><img alt="" src="/mirror/pubs/share/222186039" style="position: absolute; top: 5px; left: calc(50% - 180px); height: 380px;"/></a></p>
# </div>
# </div>
# </div>
# <section class="section section--logo">
# <div class="js-info_box_bg info_box_bg"></div>
# <div class="info_box">
# <div class="info_box__inner">
# <p>Consistently ranked as one of Russia’s top universities, the Higher School of Economics (HSE) is a leader in Russian education and one of the preeminent economics and social sciences universities in Eastern Europe and Eurasia. Having rapidly grown into a well-renowned research university over two decades, HSE sets itself apart with its international presence and cooperation. <strong style="font-size: 0.8em;"><a href="https://www.hse.ru/en/info">MORE ABOUT HSE</a></strong></p>
# </div>
# </div>
# </section>
# <section class="section">
# <div class="section__header clear">
# <h2 class="section_title"><a id="news"></a>News</h2>
# <div class="section__controls">
# <div class="section_caption">Topics</div>
# <ul class="s-rubric_list">
# <li><a class="link rubric rubric_9 s-rubric" href="/en/news/admission/"><span>Admissions</span><ins>147</ins></a></li>
# <li><a class="link rubric rubric_32 s-rubric" href="/en/news/edu/"><span>Education</span><ins>810</ins></a></li>
# <li><a class="link rubric rubric_46 s-rubric" href="/en/news/research/"><span>Research&amp;Expertise</span><ins>1522</ins></a></li>
# <li><a class="link rubric rubric_4 s-rubric" href="/en/news/society/"><span>Society</span><ins>349</ins></a></li>
# <li><a class="link rubric rubric_3 s-rubric" href="/en/news/community/"><span>Community</span><ins>179</ins></a></li>
# <li><a class="link rubric rubric_26 s-rubric" href="/en/news/campus/"><span>On Campus</span><ins>878</ins></a></li>
# </ul>
# </div>
# </div>
# <div class="column column-3">
# <div class="column__item">
# <ul class="post">
# <li class="post__item">
# <a class="link_no-underline post__img_href" href="/en/news/campus/222966241.html"><img alt="20 Things You Might Not Know About HSE - St. Petersburg" class="post__img" src="/pubs/share/thumb/223030302:c429x230+0+58:r433x232!"/></a>
# <h3 class="post__title ">
# <a href="/en/news/campus/222966241.html">20 Things You Might Not Know About HSE - St. Petersburg</a>
# </h3>
# <div class="post__descr">
# <p>Celebrating its 20<sup>th</sup> anniversary this year, HSE’s St Petersburg campus came up with the slogan ‘Time to Make Your Dreams Come True.’</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_26" href="/en/news/campus/"><span>On Campus</span></a>
# <a class="tag" href="/en/news/keywords/54787531/" title="HSE campuses">HSE campuses</a>
# <a class="tag" href="/en/news/tags/petersburg/" title="St. Petersburg">St. Petersburg</a>
# </div>
# </li>
# <li class="post__item">
# <a class="link_no-underline post__img_href" href="https://iq.hse.ru/en/news/222793842.html"><img alt="Psycholinguists Build Eye-tracking Database on Reading in Russian" class="post__img" src="/pubs/share/thumb/222917884:c433x232+0+0:r433x232!"/></a>
# <h3 class="post__title ">
# <a href="https://iq.hse.ru/en/news/222793842.html">Psycholinguists Build Eye-tracking Database on Reading in Russian</a>
# </h3>
# <div class="post__descr">
# <p>Researchers from the Higher School of Economics, St. Petersburg State University, and the University of Potsdam have created the first ever database comprised of eye-tracking data collected during reading in Russian. The results are openly available and can be used not only in linguistics, but also in the diagnosis and correction of speech disorders, for example. The research was published in the journal Behavior Research Methods.</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_46" href="/en/news/research/"><span>Research&amp;Expertise</span></a>
# <a class="tag" href="/en/news/tags/iq/" title="IQ">IQ</a>
# <a class="tag" href="/en/news/keywords/60970386/" title="psychology">psychology</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="column__item">
# <ul class="post">
# <li class="post__item">
# <a class="link_no-underline post__img_href" href="/en/news/research/222910514.html"><img alt="HSE Hosts Consortium of Higher Education Researchers Conference for the First Time" class="post__img" src="/pubs/share/thumb/223002430:c431x231+2+37:r433x232!"/></a>
# <h3 class="post__title ">
# <a href="/en/news/research/222910514.html">HSE Hosts Consortium of Higher Education Researchers Conference for the First Time</a>
# </h3>
# <div class="post__descr">
# <p>145 researchers from 30 countries discussed how higher education systems work on global and national levels, and how they are influenced by the processes of differentiation and integration.</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_46" href="/en/news/research/"><span>Research&amp;Expertise</span></a>
# <a class="tag" href="/en/news/tags/report/" title="Reporting an event">Reporting an event</a>
# <a class="tag" href="/en/news/keywords/141325152/" title=" higher education"> higher education</a>
# </div>
# </li>
# <li class="post__item">
# <a class="is-desktop link_no-underline post__img_href" href="https://www.hse.ru/en/success/bebutov/"><img alt="'Now Any Humanities Specialist Is Somewhat of a Designer'" class="post__img" src="/pubs/share/direct/223131142"/></a>
# <h3 class="post__title ">
# <a href="https://www.hse.ru/en/success/bebutov/">'Now Any Humanities Specialist Is Somewhat of a Designer'</a>
# </h3>
# <div class="post__descr">
# <p>The world is digitising. This is not a simple process for the media, as ‘ordinary’ reality and digital reality are two different worlds, themselves separate from a magazine. Trifon Bebutov, Esquire Russia’s Digital Editorial Director and a graduate of HSE’s continuing education programme in graphic design, met with Success Builder to talk about what responsibilities his job entails, what exactly ‘paper aesthetics’ means, and how bad packaging can kill amazing content.</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_4" href="/en/news/society/"><span>Society</span></a>
# <a class="tag" href="/en/news/tags/alumni/" title="alumni">alumni</a>
# <a class="tag" href="/en/news/tags/success/" title="success builder">success builder</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="column__item">
# <ul class="post">
# <li class="post__item">
# <a class="is-desktop link_no-underline post__img_href" href="/en/news/research/223024738.html"><img alt="HSE&amp;rsquo;s Institute of Education Collaborates with Global School Laboratory" class="post__img" src="/pubs/share/thumb/223157898:c1126x603+0+72:r433x232!"/></a>
# <h3 class="post__title ">
# <a href="/en/news/research/223024738.html">HSE’s Institute of Education Collaborates with Global School Laboratory</a>
# </h3>
# <div class="post__descr">
# <p>The Institute of Education at HSE has signed an agreement outlining collaboration with the online platform, GlobalLab - a community of teachers and students who work on joint research projects over the Internet.</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_46" href="/en/news/research/"><span>Research&amp;Expertise</span></a>
# <a class="tag" href="/en/news/tags/online/" title="online education">online education</a>
# <a class="tag" href="/en/news/keywords/63489055/" title="school education">school education</a>
# </div>
# </li>
# <li class="post__item">
# <a class="is-desktop link_no-underline post__img_href" href="/en/news/society/222960527.html"><img alt="HSE Launching Student Startup Competition" class="post__img" src="/pubs/share/thumb/223131229:c429x230+4+24:r433x232!"/></a>
# <h3 class="post__title ">
# <a href="/en/news/society/222960527.html">HSE Launching Student Startup Competition</a>
# </h3>
# <div class="post__descr">
# <p>The HSE Business Incubator is announcing the start of a student business project competition called the HSE{Business}Cup-2018, organised with the support of the corporate accelerator MTS StartUp Hub. The students with the best ideas will receive up to 200,000 rubles to make their projects a reality. The teams can also count on additional funds from MTS – a stipend and business grant worth 150,000 rubles.</p>
# </div>
# <div class="tag-set">
# <a class="rubric rubric_4" href="/en/news/society/"><span>Society</span></a>
# <a class="tag" href="/en/news/tags/students/" title="students">students</a>
# <a class="tag" href="/en/news/tags/inv/" title="Invitation to participate">Invitation to participate</a>
# <a class="tag" href="/en/news/keywords/44000132/" title="competition">competition</a>
# <a class="tag" href="/en/news/keywords/223008212/" title="entrepreneurship projects">entrepreneurship projects</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="section_more">
# <a href="//www.hse.ru/en/news/">All news</a>
# </div>
# </section>
# <section class="section section--abitur" style="background:url(/pubs/share/direct/182029330) 80% 20% no-repeat, url(...) 0 0 repeat-x;">
# <div class="section__header clear">
# <h2 class="section_title section_title--abitur"><a id="abitur"></a>Admissions</h2>
# </div>
# <div class="column column-8 owl-social">
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions"><img alt="International Admissions" src="/pubs/share/thumb/221401653:c150x150+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://www.hse.ru/admissions">International Admissions</a>
# <div class="from_social__content">Everything you need to know about HSE’s English-taught programmes</div>
# </div>
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/graduate-apply"><img alt="English-taught Master’s Programmes" src="/pubs/share/thumb/221401660:c150x150+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://www.hse.ru/admissions/graduate-apply">English-taught Master’s Programmes</a>
# <div class="from_social__content">Choose from more than 20 programmes</div>
# </div>
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/undergraduate-apply"><img alt="English-taught Bachelor’s Programmes" src="/pubs/share/thumb/221401667:c150x150+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://www.hse.ru/admissions/undergraduate-apply">English-taught Bachelor’s Programmes</a>
# <div class="from_social__content">Earn a double-degree from HSE and University of London in economics or international relations</div>
# </div>
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/fees&amp;funding"><img alt="Programme Fees" src="/pubs/share/thumb/221401673:c150x150+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://www.hse.ru/admissions/fees&amp;funding">Programme Fees</a>
# <div class="from_social__content">Learn about programme costs</div>
# </div>
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://istudents.hse.ru/"><img alt="International Student Life" src="/pubs/share/thumb/221401687:c150x150+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://istudents.hse.ru/">International Student Life</a>
# <div class="from_social__content">Find out what it’s like to study at HSE and live in Moscow</div>
# </div>
# <div class="column__item">
# <a class="from_social__image from_social__image--abitur" href="https://visa.hse.ru/en/obtain"><img alt="Visa Support" src="/pubs/share/thumb/222541537:c667x667+0+0:r150x150!"/></a>
# <a class="from_social__title" href="https://visa.hse.ru/en/obtain">Visa Support</a>
# <div class="from_social__content">How to apply for a Russian visa</div>
# </div>
# <section class="section section--brown">
# <div class="section__header clear">
# <h2 class="section_title section_title--brown section__events big_counter" data-count="28" data-counter="28"><a id="events"></a>Events</h2>
# <div class="section__controls" lang="en">
# <ul class="filter">
# <li class="filter__item"><input class="filter__input filter__input--theme" data-count="7" id="filter_theme__item_1" type="checkbox" value="1"/><label class="filter__label filter__label--theme" for="filter_theme__item_1">educational</label></li>
# <li class="filter__item"><input class="filter__input filter__input--theme" data-count="20" id="filter_theme__item_2" type="checkbox" value="2"/><label class="filter__label filter__label--theme" for="filter_theme__item_2">research</label></li>
# <li class="filter__item"><input class="filter__input filter__input--theme" data-count="1" id="filter_theme__item_3" type="checkbox" value="3"/><label class="filter__label filter__label--theme" for="filter_theme__item_3">cultural, entertainment and leisure</label></li>
# </ul>
# </div>
# </div>
# <div class="column events__box column-6 owl-carousel">
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 10 – Sep 14</div>
# <p class="events__descr">International Summer School '<a href="https://ling.hse.ru/indling/">Areal Linguistics and Languages of Russia</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 11</div>
# <p class="events__hour">18:10</p>
# <p class="events__descr"><a href="https://cs.hse.ru/en/announcements/221409531.html">Colloquium: Computational Cognitive Neuroscience: A Brief Primer</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 12</div>
# <p class="events__hour">16:00</p>
# <p class="events__descr">Riitta Salmelin to speak on '<a href="/en/news/222965753.html">MEG Measures as Probes of Cortical Language Function</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 12</div>
# <p class="events__hour">17:00</p>
# <p class="events__descr">Mehmet Huseyin Bilgin to speak on '<a href="https://we.hse.ru/en/announcements/223132312.html">Socio-Economic Development of Modern Turkey</a>'</p>
# </div>
# <div class="column__item event-category-3 is-visible">
# <div class="events__time">Sep 13</div>
# <p class="events__hour">14:00</p>
# <p class="events__descr"><a href="https://www.hse.ru/en/day2018/">HSE Day</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 13</div>
# <p class="events__hour">18:00</p>
# <p class="events__descr">Stephen Kowalewski to speak on '<a href="/en/news/223024850.html">Advances in City-State Research, with an Example from Mesoamerica</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 15</div>
# <p class="events__hour">10:00</p>
# <p class="events__descr"><a href="https://icef.hse.ru/en/announcements/222585190.html">First ICEF Conference in Applied Economics</a></p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 15</div>
# <p class="events__hour">15:00</p>
# <p class="events__descr">Performance of the Modern Playback Theater '<a href="https://www.hse.ru/en/cpc/announcements/222512104.html">The Dialogue between Cultures</a>'</p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 17</div>
# <p class="events__hour">12:00</p>
# <p class="events__descr"><a href="https://fmlab.hse.ru/en/announcements/222762535.html">Meeting with Professor A. Fasano for lecturers and students of Master's programme 'Financial Markets and Institutions'</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 17</div>
# <p class="events__hour">13:40</p>
# <p class="events__descr"><a href="https://economics.hse.ru/en/announcements/222965760.html">FES International Research Seminar</a> on Financial Globalization and the Welfare State</p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 18</div>
# <p class="events__hour">12:10</p>
# <p class="events__descr"><a href="https://fmlab.hse.ru/en/announcements/222762697.html">Professor A. Fasano to talk about practical lessons on integration of Bloomberg and R</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 18</div>
# <p class="events__hour">18:10</p>
# <p class="events__descr">Gernot Saalmann to speak '<a href="/en/news/223114435.html">Modernity, Modernization and Globalization: Taking a Look at India</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 19 – Sep 22</div>
# <p class="events__descr"><a href="https://amec.hse.ru/">Analytics for Management and Economics Conference</a></p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 20</div>
# <p class="events__hour">15:10</p>
# <p class="events__descr"><a href="https://fmlab.hse.ru/en/announcements/222762756.html">Professor A. Fasano to give a research seminar in financial economics for students of Master's programme in Financial Markets and Institutions</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 21 – Sep 22</div>
# <p class="events__descr"><a href="https://icare.hse.ru/2018/">6th International Conference on Applied Research in Economics</a> (iCare6)</p>
# <div class="events__comment grey">
# <p>Submission of papers (full draft) – May 31, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 21</div>
# <p class="events__hour">18:00</p>
# <p class="events__descr">Wolfgang Kissel to speak on '<a href="https://reid.hse.ru/en/announcements/222989227.html">From the October Revolution to Soviet Civilization: On the Emergence and Transformation of a Stalinist Discourse</a>'</p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 24 – Oct 5</div>
# <p class="events__descr">International Autumn school '<a href="https://demogr.hse.ru/en/school">Demographic methods in public health research</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Sep 24 – Sep 27</div>
# <p class="events__descr"><a href="https://csp.hse.ru/en/2018/">III International Conference on Computer Simulation in Physics and beyond</a></p>
# </div>
# <div class="column__item event-category-1 is-visible">
# <div class="events__time">Sep 25</div>
# <p class="events__hour">13:00</p>
# <p class="events__descr">Living and Working in Russia: <a href="https://ifaculty.hse.ru/announcements/222500352.html">Workshop for International Faculty</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Oct 11 – Oct 12</div>
# <p class="events__descr">2nd IZA/HSE Workshop: <a href="https://www.hse.ru/en/org/hse/clms/announcements/216771555.html">Ten Years after the Financial Crisis - Labor Market Adjustment in Emerging and Post-Transition Economies</a></p>
# <div class="events__comment grey">
# <p>Paper submission deadline – June 15, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Oct 12</div>
# <p class="events__descr">8th Annual CInSt Banking Workshop '<a href="https://cinst.hse.ru/en/announcements/218173839.html">Banking in Emerging Markets: Challenges and Opportunities</a>'</p>
# <div class="events__comment grey">
# <p>Deadline for submission: June 17, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Oct 24 – Oct 25</div>
# <p class="events__descr"><a href="https://uni.hse.ru/en/announcements/221809933.html">IPA Symposium in Higher Education at the International Russian Higher Education Conference</a></p>
# <div class="events__comment grey">
# <p>Submission deadline - September 15, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Oct 26 – Oct 27</div>
# <p class="events__descr"><a href="/en/news/220944366.html">Seventh International Moscow Finance and Economics Conference</a></p>
# <div class="events__comment grey">
# <p>Deadline for submissions: July 20, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Nov 12 – Nov 13</div>
# <p class="events__descr">International Conference '<a href="https://ioe.hse.ru/en/celcon/">Multilevel Governance in Education: Top-Down Governance, Transfer of Authority and Regional Cooperation</a>'</p>
# <div class="events__comment grey">
# <p>Deadline for submissions: August 15, 2018<span class="with-icon with-icon_flag2 with-icon_right"> </span></p>
# </div>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Nov 16 – Nov 17</div>
# <p class="events__hour">11:00</p>
# <p class="events__descr">International Seminar of the School of Finance '<a href="https://finance.hse.ru/en/announcements/222631804.html">Systemic Risk in the Financial Sector</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Nov 29 – Dec 1</div>
# <p class="events__descr"><a href="/en/news/221356125.html">International Forum for Young Scholars of Soviet and Post-Soviet History and Culture</a></p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Nov 30 – Dec 1</div>
# <p class="events__descr">Fifth International Conference '<a href="https://social.hse.ru/en/bispsy/2018/">Business Psychology: Theory and Practice</a>'</p>
# </div>
# <div class="column__item event-category-2 is-visible">
# <div class="events__time">Dec 5 – Dec 6</div>
# <p class="events__descr"><a href="https://estars.hse.ru/eng">eLearning Stakeholders and Researchers Summit 2018</a></p>
# </div>
# </div>
# <div class="section_more t-events">
# <a href="//www.hse.ru/en/news/announcements/">All events</a>
# <a class="subscribe_button" href="https://www.hse.ru/en/news/announcements/?mode=expand&amp;subscribe=1">Subscribe</a>
# </div>
# </section>
# <section class="section section--social">
# <div class="section__header clear">
# <h2 class="section_title section_title--social">
# <a id="around_hse"></a>
#
# 						Around HSE
#
# 				</h2>
# </div>
# <div class="column column-8 owl-social">
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BjC5iRZh6gx/" rel="nofollow"><img alt="@kattynuts" src="/pubs/share/cover/thumb/219535328x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/kattynuts/" rel="nofollow">@kattynuts</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BjC5iRZh6gx/" rel="nofollow">The light of HSE</a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BhEZq_Ag9ex/" rel="nofollow"><img alt="@harbour.space" src="/pubs/share/cover/thumb/217813864x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/harbour.space/" rel="nofollow">@harbour.space</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BhEZq_Ag9ex/" rel="nofollow">The International Data Analysis Olympiad is going. HSE participated in its organization. </a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BgY8d5IAVw6/" rel="nofollow"><img alt="@_dariachaban_" src="/pubs/share/cover/thumb/217260352x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/_dariachaban_/" rel="nofollow">@_dariachaban_</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BgY8d5IAVw6/" rel="nofollow">Thinking about HSE in one of our dorms</a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BgNsDwMAzIb/" rel="nofollow"><img alt="@sima_bright" src="/pubs/share/cover/thumb/217260312x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/sima_bright/" rel="nofollow">@sima_bright</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BgNsDwMAzIb/" rel="nofollow">Spring sky over the HSE building </a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/Be2LblbnJtH/" rel="nofollow"><img alt="@vandervetrov/" src="/pubs/share/cover/thumb/215789086x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/vandervetrov/" rel="nofollow">@vandervetrov/</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/Be2LblbnJtH/" rel="nofollow">Rock-noodle in HSE Art and Design School</a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BedjTEHHaKY/" rel="nofollow"><img alt=" @maybe_natasha " src="/pubs/share/cover/thumb/214823046x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/maybe_natasha/" rel="nofollow"> @maybe_natasha </a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BedjTEHHaKY/" rel="nofollow">Poster at HSE Art and Design School</a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BeOpTNUhJOu/" rel="nofollow"><img alt="@tnkmnsk" src="/pubs/share/cover/thumb/214823847x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/tnkmnsk/" rel="nofollow">@tnkmnsk</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BeOpTNUhJOu/" rel="nofollow">Winter in HSE St. Petersburg</a></div>
# </div>
# <div class="column__item">
# <div class="from_social__network media-ico-blue media-ico-blue_instagram"></div>
# <a class="from_social__image" href="https://www.instagram.com/p/BaZZq5OHgiq/?taken-by=margaritavlas" rel="nofollow"><img alt="@margaritavlas" src="/pubs/share/cover/thumb/213942794x135x110"/></a>
# <a class="from_social__author" href="https://www.instagram.com/margaritavlas/" rel="nofollow">@margaritavlas</a>
# <div class="from_social__content"><a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BaZZq5OHgiq/?taken-by=margaritavlas" rel="nofollow">Melancholy HSE clock </a></div>
# </div>
# </div>
# </section>
# <section class="section section--contacts">
# <div class="section__header clear">
# <h2 class="section_title section_title--light"><a id="contacts"></a>Contacts</h2>
# <div class="section__controls">
# </div>
# </div>
# <div class="column column-5">
# <div class="column__item">
# <p class="b">International Admissions</p>
# <p><a href="mailto:inter@hse.ru">inter@hse.ru</a></p>
# <p><a href="http://www.hse.ru/admissions">www.hse.ru/admissions</a></p>
# <p>+7 (495) 531-00-59</p>
# <p> </p>
# <p><a href="http://www.hse.ru/en/buildinghse/">Map of HSE Buildings</a></p>
# </div>
# <div class="column__item">
# <p class="b">International Students Support</p>
# <p><a class="link" href="mailto:international.study@hse.ru">international.study@hse.ru</a></p>
# <p><a href="http://istudents.hse.ru/">istudents.hse.ru</a></p>
# <p>+7 (495) 772-95-90, ext. 12468</p>
# <p> </p>
# <p><strong>Main campus</strong>: 20 Myasnitskaya Ulitsa</p>
# </div>
# <div class="column__item">
# <p class="b">International Faculty Recruitment</p>
# <p><a href="mailto:iri@hse.ru" target="_blank">iri@hse.ru</a></p>
# <p><a href="https://iri.hse.ru/">iri.hse.ru</a></p>
# <p>+7 (495) 772-95-90, ext. 11009</p>
# </div>
# <div class="column__item">
# <p class="b">International Faculty Support</p>
# <p><a href="mailto:ifaculty.support@hse.ru">ifaculty.support@hse.ru</a></p>
# <p><a href="http://ifaculty.hse.ru/">ifaculty.hse.ru</a></p>
# <p>+7 (495) 772-95-90 *12504</p>
# </div>
# <div class="column__item">
# <p class="b">PR Office</p>
# <p><a href="mailto:press@hse.ru">press@hse.ru</a></p>
# <p><a href="https://pr.hse.ru/en/">pr.hse.ru/en/</a></p>
# <p>+7 495 772 9567</p>
# </div>
# </div>
# </section>
# <footer class="footer section">
# <div class="footer__navigation column column-5">
# <ul class="navigation column__item">
# <li class="navigation__item navigation__item--parent">
# <a class="navigation__link" href="https://www.hse.ru/en/info/">About</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://www.hse.ru/en/info/">About</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/figures/">Key Figures &amp; Facts</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/education/faculty/">Faculties &amp; Departments</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/intpartners/">International Partnerships</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/org/persons/">Faculty &amp; Staff</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://www.hse.ru/en/buildinghse/">HSE Buildings</a>
# </li>
# </ul>
# <ul class="navigation column__item">
# <li class="navigation__item navigation__item--parent">
# <a class="navigation__link" href="http://www.hse.ru/en/education/">Studies</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/admissions">Admissions</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/education/">Programme Catalogue</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/admissions/undergraduate-apply">Undergraduate</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/admissions/graduate-apply">Graduate</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/admissions/exchange-apply">Exchange Programmes</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/international/summer">Summer University</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/sumschool/">Summer Schools</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/international/semester">Semester in Moscow</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://iiab.hse.ru/en/mib">Business Education</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/doingbusiness">Business Internship</a>
# </li>
# </ul>
# <ul class="navigation column__item">
# <li class="navigation__item navigation__item--parent">
# <a class="navigation__link" href="http://www.hse.ru/en/science/">Research</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/interlabs/">International Laboratories</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://www.hse.ru/en/science/centers/">Research Centres</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/org/projects/">Research Projects</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/monitoring/">Monitoring Studies</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/science/conferences">Conferences &amp; Seminars</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://iri.hse.ru/">Academic Jobs</a>
# </li>
# </ul>
# <ul class="navigation column__item">
# <li class="navigation__item navigation__item--parent">
# <a class="navigation__link" href="http://www.hse.ru/en/pubs.html">Media &amp; Resources</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://publications.hse.ru/en/">Publications by staff</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://www.hse.ru/en/science/journals">HSE Journals</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://id.hse.ru/en/">Publishing House</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://iq.hse.ru/en/">iq.hse.ru: commentary by HSE experts</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://library.hse.ru/en/">Library</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://sophist.hse.ru/eng/">Economic &amp; Social Data Archive</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://www.youtube.com/playlist?list=PL-U1Z5tJ1i-YhBCL9qUCaTf9cN8TF67VR " rel="nofollow">Video</a>
# </li>
# </ul>
# <ul class="navigation column__item">
# <li class="navigation__item navigation__item--parent">
# <a class="navigation__link" href="//www.hse.ru/en/">Useful Links</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://elearning.hse.ru/en/mooc/">Massive Open Online Courses</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="https://www.hse.ru/en/visual/">HSE Site for the Visually Impaired</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="http://5top100.com/" rel="nofollow">Russian Academic Excellence Project 5-100</a>
# </li>
# </ul>
# </div>
# <div class="footer__bottom">
# <a id="sitemap"></a>
# <div class="editor"><!--noindex--><a class="link" href="//www.hse.ru/en/adm/?newportal=1" rel="nofollow">Edit</a><!--/noindex--></div>
# <div class="footer__navigation">
# <ul class="navigation navigation--horiz footer__copyright">
# <li class="navigation__item grey">© HSE 1993–2018</li>
# <li class="navigation__item"><a href="http://www.hse.ru/en/contacts.html">Contacts</a></li>
# <li class="navigation__item"><a href="http://www.hse.ru/en/copyright">Copyright</a></li>
# <li class="navigation__item"><a href="https://www.hse.ru/en/data_protection_regulation">Privacy Policy</a></li>
# <li class="navigation__item"><a href="http://www.hse.ru/en/sitemap.html">Site Map</a></li>
# </ul>
# </div>
# <div class="footer__copyright">
#
# 					Webpage design by HSE Design Lab
#
# 			</div>
# </div>
# </footer>
# </div>
# </section></div>
# </div></body>
# </html>

# %%
# можно добавить форматирование, чтобы стало красиво
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    National Research University Higher School of Economics
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="25e3420f8bfc397e" name="yandex-verification"/>
#   <meta content="#1658DA" name="theme-color"/>
#   <meta content="SB2V6wrEtxYZNqgs" name="sputnik-verification"/>
#   <link href="https://www.hse.ru/f/src/manifest/manifest_en.json" rel="manifest"/>
#   <link href="//www.hse.ru/en/" rel="canonical"/>
#   <link href="/f/src/global/css/main_fonts.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/main_icons.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/main_forms.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/fotorama.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/sitemap.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/main_hse.css" rel="stylesheet"/>
#   <link href="/f/src/home/main_en.css" rel="stylesheet"/>
#   <link href="/f/src/home/owl.carousel.css" rel="stylesheet"/>
#   <link href="/f/src/global/css/vision.css" rel="stylesheet"/>
#   <!--[if lt IE 10]><script src="/f/src/global/bower_components/es5-shim/es5-shim.min.js"></script><![endif]-->
#   <script src="/f/src/global/js/cache/jquery-1.10.1.min/jquery.cookie/hse.utils/main/ctrlshifte/popup/fotorama/owl.carousel.min/home_en/edu_mobile/modernizr/sitemap.ajax/android/vision/sw-register.js" type="text/javascript">
#   </script>
#   <script src="/f/src/global/bower_components/jquery-ui/ui/effect.js" type="text/javascript">
#   </script>
#   <script src="/f/src/global/bower_components/moment/min/moment-with-locales.min.js" type="text/javascript">
#   </script>
#   <script src="/f/src/global/bower_components/jquery-bigtext/jquery-bigtext.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function() {
# 			var s = document.createElement('script');
# 			s.type = 'text/javascript'; s.async = true;
# 			s.src = '/f/src/_/jquery.orfo.js';
# 			s.onload = s.onreadystatechange = function() {
# 				if ($.fn.hseOrfo) {	// old IE...
# 					$(document).hseOrfo({
# 						'lang': 'en'
# 					});
# 				}
# 			};
# 			var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(s, t);
# 		})();
#   </script>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="National Research University Higher School of Economics" property="og:title"/>
#   <meta content="National Research University Higher School of Economics" name="mrc__share_title"/>
#   <meta content="National Research University Higher School of Economics" itemprop="name"/>
#   <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" property="og:description"/>
#   <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" name="mrc__share_description"/>
#   <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" itemprop="description"/>
#   <meta content="HSE is one of the top universities in Russia and the leader in Eastern Europe and Eurasia in economics and social sciences" name="twitter:description"/>
#   <meta content="https://www.hse.ru/images/fb/hse_en_thumb.jpg" property="og:image"/>
#   <meta content="https://www.hse.ru/images/fb/hse_en_thumb.jpg" itemprop="image"/>
#   <link href="https://www.hse.ru/images/fb/hse_en_thumb.jpg" rel="image_src"/>
#   <meta content="" name="twitter:image"/>
#   <meta content="//www.hse.ru/en/" property="og:url"/>
#   <meta content="//www.hse.ru/en/" name="twitter:url"/>
#   <meta content="website" property="og:type"/>
#   <style>
#    .main_slider__item.interstud {background-position: 50% 30%;}
#
#
#
# 				.main_slider__item.niwork {background-position: 50% 20%;}
#
#
#
# 				.day18.main_slider__item {background-position: 50% 50%;}
# @media screen and (max-width: 768px) {
# 	.day18 .day18_logo {display: none;}
# }
# @media screen and (min-width: 769px) {
# 	.day18 h3 {display: none;}
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			.section--abitur .section_title, .section_title--abitur, .c-abitur {
# 				color: #2c8fc0;
# 			}
#
# 			.section--abitur .owl-prev { border-left-color: #2c8fc0; border-bottom-color: #2c8fc0; }
# 			.section--abitur .owl-next { border-right-color: #2c8fc0; border-bottom-color: #2c8fc0;}
# 			.section--abitur .owl-pagination::after {
# 				background-image: linear-gradient(to right, #2c8fc0, rgba(202,228,146,.2));
# 			}
#
# 			.section--abitur .owl-pagination::before {
# 				background-image: linear-gradient(to left, #2c8fc0, rgba(202,228,146,.2));
# 			}
#
# 			.section--abitur  .owl-page span {
# 				background: #2c8fc0;
# 			}
#
# 			.section--abitur  .owl-page.active span {
# 				border-color: #2c8fc0;
# 			}
#   </style>
#   <script type="text/javascript">
#    <!--
# (function (d, w, c) {
# 							(w[c] = w[c] || []).push(function() {
# 											try {
# 															w.yaCounter32635220 = new Ya.Metrika({
# 																			id:32635220,
# 																			clickmap:true,
# 																			trackLinks:true,
# 																			accurateTrackBounce:true
# 															});
#
# 															w.yaCounter36283385 = new Ya.Metrika({
# 																			id:36283385,
# 																			clickmap:true,
# 																			trackLinks:true,
# 																			accurateTrackBounce:true,
# 																			trackHash:true,
# 																			webvisor:true
# 															});
# 											} catch(e) { }
# 							});
#
# 							var n = d.getElementsByTagName("script")[0],
# 											s = d.createElement("script"),
# 											f = function () { n.parentNode.insertBefore(s, n); };
# 							s.type = "text/javascript";
# 							s.async = true;
# 							s.src = "https://mc.yandex.ru/metrika/watch.js";
#
# 							if (w.opera == "[object Opera]") {
# 											d.addEventListener("DOMContentLoaded", f, false);
# 							} else { f(); }
# 			})(document, window, "yandex_metrika_callbacks");
#  var _gaq = _gaq || [];
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P6DCQX');
# //-->
#   </script>
#  </head>
#  <body data-lang="en">
#   <div class="page">
#    <!--noindex-->
#    <div class="browser_outdate" style="display:none;">
#     В старых версиях браузеров сайт может отображаться некорректно. Для оптимальной работы с сайтом рекомендуем воспользоваться современным браузером.
#    </div>
#    <div class="gdpr_bar" style="display:none;">
#     <div class="gdpr_bar__inner">
#      <p>
#       We use cookies in order to improve the quality and usability of the HSE website. More information about the use of cookies is available
#       <a href="https://www.hse.ru/en/cookie.html">
#        here
#       </a>
#       , and the regulations on processing personal data can be found
#       <a href="https://www.hse.ru/en/data_protection_regulation">
#        here
#       </a>
#       . By continuing to use the site, you hereby confirm that you have been informed of the use of cookies by the HSE website and agree with our rules for processing personal data. You may disable cookies in your browser settings.
#      </p>
#      <span class="gdpr_bar__close">
#       ✖
#      </span>
#     </div>
#    </div>
#    <!--/noindex-->
#    <div class="sv-control">
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-size">
#       <li class="sv-control__item sv-control__item--s_normal active" data-type="size" data-value="normal">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_medium" data-type="size" data-value="medium">
#        A
#       </li>
#       <li class="sv-control__item sv-control__item--s_large" data-type="size" data-value="large">
#        A
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-spacing">
#       <li class="active sv-control__item sv-control__item--ls_normal" data-type="spacing" data-value="normal">
#        ABC
#       </li>
#       <li class="sv-control__item sv-control__item--ls_medium" data-type="spacing" data-value="medium">
#        ABC
#       </li>
#       <li class="sv-control__item sv-control__item--ls_large" data-type="spacing" data-value="large">
#        ABC
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-contrast">
#       <li class="sv-control__item sv-control__item---color1 active" data-type="contrast" data-value="normal">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color2" data-type="contrast" data-value="invert">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color3" data-type="contrast" data-value="blue">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color4" data-type="contrast" data-value="beige">
#        А
#       </li>
#       <li class="sv-control__item sv-control__item---color5" data-type="contrast" data-value="brown">
#        А
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <ul class="sv-control__list sv-image">
#       <li class="sv-control__item sv-control__item--image_on active" data-type="image" data-value="on">
#       </li>
#       <li class="sv-control__item sv-control__item--image_off" data-type="image" data-value="off">
#       </li>
#      </ul>
#     </div>
#     <div class="sv-control__block">
#      <div class="sv-off js-sv-off">
#       Regular version of the site
#      </div>
#     </div>
#    </div>
#    <div class="layout">
#     <div class="header-top">
#      <div class="left is-desktop">
#       <span class="control control_sitemap control_hidden">
#        <span class="control_sitemap__line">
#        </span>
#       </span>
#      </div>
#      <div class="right">
#       <div class="header__controls">
#        <span class="control control_wider control_campus is-mobile">
#         <span class="popup_opener campus with-icon with-icon_right with-icon_sortdown">
#          Campus:
#          <ins class="campus__emblem campus__emblem--msk">
#          </ins>
#          <span class="campus__name">
#           Moscow
#          </span>
#         </span>
#         <div class="popup popup_campus-select popup_campus-relative not_display">
#          <ul class="navigation smaller">
#           <li>
#            <a class="link no-visited with-icon with-icon_flag-nn" href="http://nnov.hse.ru/en/">
#             Nizhny Novgorod
#            </a>
#           </li>
#           <li>
#            <a class="link no-visited with-icon with-icon_flag-spb" href="http://spb.hse.ru/en/">
#             Saint Petersburg
#            </a>
#           </li>
#           <li>
#            <a class="link no-visited with-icon with-icon_flag-perm" href="http://perm.hse.ru/en/">
#             Perm
#            </a>
#           </li>
#          </ul>
#         </div>
#        </span>
#        <span class="campus_list is-desktop">
#         <span class="campus">
#          Campus:
#          <ins class="campus__emblem campus__emblem--msk">
#          </ins>
#          <span class="campus__name">
#           Moscow
#          </span>
#         </span>
#         <a class="campus_list__item link_no-underline link no-visited" href="http://nnov.hse.ru/en/">
#          Nizhny Novgorod
#         </a>
#         <a class="campus_list__item link_no-underline link no-visited" href="http://spb.hse.ru/en/">
#          Saint Petersburg
#         </a>
#         <a class="campus_list__item link_no-underline link no-visited" href="http://perm.hse.ru/en/">
#          Perm
#         </a>
#        </span>
#        <span class="control control_wider is-desktop">
#         <a class="m-link_white" href="//www.hse.ru/cn">
#          中文版
#         </a>
#        </span>
#        <ul class="control_lang2 is-desktop">
#         <li class="control_lang2_item first_child">
#          <a class="link link_no-visited link_no-underline" href="//www.hse.ru/">
#           RU
#          </a>
#         </li>
#         <li class="control_lang2_item activated last_child">
#          <a class="link link_no-visited link_no-underline" href="//www.hse.ru/en/">
#           EN
#          </a>
#         </li>
#        </ul>
#        <span class="control control_vision is-desktop" title="For visually-impaired">
#         <svg height="12" viewbox="0 0 21 12" width="21" xmlns="http://www.w3.org/2000/svg">
#          <title>
#           vision
#          </title>
#          <path d="M10.5 0c3.438 0 6.937 2.016 10.5 6.047-.844.844-1.383 1.375-1.617 1.594-.234.219-.805.703-1.711 1.453-.906.75-1.641 1.266-2.203 1.547-.563.281-1.305.578-2.227.891-.922.313-1.836.469-2.742.469-1.125 0-2.156-.141-3.094-.422-.938-.281-1.875-.766-2.813-1.453-.938-.688-1.672-1.273-2.203-1.758-.531-.484-1.328-1.273-2.391-2.367 2.031-2.031 3.836-3.539 5.414-4.523 1.578-.984 3.273-1.477 5.086-1.477zm0 10.266c1.156 0 2.148-.422 2.977-1.266.828-.844 1.242-1.844 1.242-3s-.414-2.156-1.242-3c-.828-.844-1.82-1.266-2.977-1.266-1.156 0-2.148.422-2.977 1.266-.828.844-1.242 1.844-1.242 3s.414 2.156 1.242 3c.828.844 1.82 1.266 2.977 1.266zm0-5.766c0 .438.141.797.422 1.078s.641.422 1.078.422c.313 0 .625-.109.938-.328v.328c0 .688-.234 1.273-.703 1.758-.469.484-1.047.727-1.734.727-.688 0-1.266-.242-1.734-.727-.469-.484-.703-1.07-.703-1.758s.234-1.273.703-1.758c.469-.484 1.047-.727 1.734-.727h.375c-.25.313-.375.641-.375.984z" fill="#1658DA">
#          </path>
#         </svg>
#        </span>
#        <a class="control control_user is-desktop" href="https://www.hse.ru/en/user/" title="User profile (HSE staff only)">
#         <ins>
#          <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#           <title>
#            user
#           </title>
#           <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#           </path>
#          </svg>
#         </ins>
#        </a>
#        <span class="control control_search is-desktop" title="Search">
#         <ins class="popup_opener">
#          <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#           <title>
#            search
#           </title>
#           <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#           </path>
#          </svg>
#         </ins>
#         <div class="popup popup_search popup_campus-relative not_display">
#          <div class="popup__inner">
#           <div class="search-form">
#            <form action="//www.hse.ru/en/search/index.html">
#             <div class="search-form__button">
#              <button class="button button_grey">
#               Search
#              </button>
#             </div>
#             <div class="search-form__input">
#              <input class="input input100 input_mr" name="text" placeholder="Looking for..." type="text"/>
#              <input name="simple" type="hidden" value="1"/>
#              <input name="searchid" type="hidden" value="2284688"/>
#             </div>
#            </form>
#           </div>
#           <div class="popup_search__text">
#            <a class="link link_dark no-visited" href="//www.hse.ru/en/search/search.html?simple=0&amp;searchid=2284688">
#             Advanced search
#            </a>
#            <span class="b-adv-search">
#            </span>
#           </div>
#          </div>
#         </div>
#        </span>
#        <span class="control is-mobile control_menu js-control_menu_open" onclick="void(0)">
#         <ins>
#         </ins>
#        </span>
#       </div>
#      </div>
#      <div class="header__body">
#       <ul class="navigation navigation--social" style="visibility:hidden;">
#        <li class="navigation__item">
#         <a class="external with-icon with-icon_fb-blue link" href="https://www.facebook.com/HSE.english" target="_blank" title="Facebook">
#          <span class="navigation__title">
#           Facebook
#          </span>
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a class="external with-icon with-icon_tw-blue link" href="https://twitter.com/HSE_eng" target="_blank" title="Twitter">
#          <span class="navigation__title">
#           Twitter
#          </span>
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a class="external with-icon with-icon_inst-blue link" href="https://www.instagram.com/hse_university/" target="_blank" title="Instagram">
#          <span class="navigation__title">
#           Instagram
#          </span>
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a class="external with-icon with-icon_in-blue link" href="https://www.linkedin.com/edu/school?id=17073" rel="nofollow" target="_blank" title="LinkedIn">
#          <span class="navigation__title">
#           LinkedIn
#          </span>
#         </a>
#        </li>
#        <li class="navigation__item">
#         <a class="external with-icon with-icon_yt-blue link" href="https://www.youtube.com/playlist?list=PL-U1Z5tJ1i-YhBCL9qUCaTf9cN8TF67VR" rel="nofollow" target="_blank" title="YouTube">
#          <span class="navigation__title">
#           YouTube
#          </span>
#         </a>
#        </li>
#        <li class="navigation__item js-more">
#         <span class="with-icon with-icon_dots-blue js-social_popup_control link">
#         </span>
#         <ul class="navigation popup navigation--social_popup js-social_popup">
#          <li>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <header class="header clear">
#      <ul class="navigation navigation--target header__nav">
#       <li class="navigation__item c-navy">
#        <a href="#news">
#         News
#        </a>
#       </li>
#       <li class="navigation__item c-abitur" style="color:#2c8fc0">
#        <a href="#abitur">
#         Admissions
#        </a>
#       </li>
#       <li class="navigation__item c-olive_dark">
#        <a href="#events">
#         Events
#        </a>
#       </li>
#       <li class="navigation__item c-orange">
#        <a href="#around_hse">
#         Around HSE
#        </a>
#       </li>
#       <li class="navigation__item c-gray">
#        <a href="#contacts">
#         Contacts
#        </a>
#       </li>
#       <li class="navigation__item c-navy">
#        <a href="#sitemap">
#         Sitemap
#        </a>
#       </li>
#      </ul>
#      <div class="logo">
#       <img alt="" class="logo__img" src="/images/main_en/hse_en_logo.svg"/>
#       <div class="logo__box">
#        <h1 class="logo__title">
#         Higher School of Economics
#        </h1>
#        <span class="logo__subtitle">
#         National Research University
#        </span>
#       </div>
#      </div>
#      <div class="header__content is-desktop">
#       <div class="header__link">
#        <ul class="navigation js-mobile_menu_content navigation--tight">
#         <li class="navigation__item">
#          <a href="http://www.hse.ru/en/education/faculty/">
#           Faculties and Institutes
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a href="http://www.hse.ru/en/org/persons/">
#           Faculty &amp; Staff
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a href="http://www.hse.ru/intpartners">
#           International Partnerships
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a href="https://iri.hse.ru/">
#           Academic Jobs
#          </a>
#         </li>
#         <li class="navigation__item">
#          <a href="http://alumni.hse.ru/en/">
#           Alumni
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="header__important">
#        <a class="header__important_in js-mobile_menu_content link_no-underline" href="https://www.hse.ru/en/our/">
#         <span class="important">
#          University Life
#         </span>
#         <p class="c-gray">
#          Information for students &amp; faculty
#         </p>
#        </a>
#       </div>
#      </div>
#     </header>
#     <div class="js-mobile_popup fa-sidebar">
#      <div class="header-board__top fa-sidebar__top--secondary js-mobile_popup__top is-fixed is-mobile">
#       <div class="header-top fa-sidebar__top--secondary">
#        <div class="left">
#         <span class="control control_wider">
#          <a href="//www.hse.ru/cn">
#           中文版
#          </a>
#         </span>
#         <ul class="control_lang2">
#          <li class="control_lang2_item first_child">
#           <a class="link link_no-visited link_no-underline" href="//www.hse.ru/">
#            RU
#           </a>
#          </li>
#          <li class="control_lang2_item activated last_child">
#           <a class="link link_no-visited link_no-underline" href="//www.hse.ru/en/">
#            EN
#           </a>
#          </li>
#         </ul>
#         <a class="control control_user control_white" href="https://www.hse.ru/en/user/" title="User profile (HSE staff only)">
#          <ins>
#           <svg class="control_svg" height="18" viewbox="0 0 17 18" width="17" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             user
#            </title>
#            <path d="M13.702 13.175c.827.315 1.486.817 1.978 1.506.492.689.738 1.467.738 2.333h-16.419c0-1.417.532-2.5 1.595-3.248.394-.276 1.358-.591 2.894-.945.945-.118 1.457-.374 1.536-.768.039-.157.059-.61.059-1.358 0-.118-.039-.217-.118-.295-.157-.157-.315-.433-.472-.827-.079-.315-.157-.787-.236-1.417-.157.039-.285-.02-.384-.177-.098-.157-.177-.364-.236-.62l-.089-.443c-.157-.866-.098-1.28.177-1.24-.118-.157-.217-.532-.295-1.122-.118-.866-.059-1.634.177-2.303.276-.748.768-1.319 1.476-1.713.709-.394 1.476-.571 2.303-.532.787.039 1.506.276 2.156.709.65.433 1.093 1.024 1.329 1.772.197.551.217 1.319.059 2.303-.079.472-.157.768-.236.886.118-.039.207 0 .266.118.059.118.079.266.059.443l-.059.472c-.02.138-.049.246-.089.325l-.118.413c-.039.276-.108.472-.207.591-.098.118-.226.157-.384.118-.079.866-.217 1.476-.413 1.831 0 .039-.069.138-.207.295-.138.157-.207.256-.207.295v.65c0 .394.039.689.118.886.079.197.354.354.827.472.276.118.679.217 1.211.295.532.079.935.177 1.211.295z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#         </a>
#         <span class="control control_white control_search js-search_mobile_control" title="Search">
#          <ins>
#           <svg class="control_svg" height="19" viewbox="0 0 19 19" width="19" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             search
#            </title>
#            <path d="M12.927 7.9c0-1.384-.492-2.568-1.476-3.552s-2.168-1.476-3.552-1.476-2.568.492-3.552 1.476-1.476 2.168-1.476 3.552.492 2.568 1.476 3.552 2.168 1.476 3.552 1.476 2.568-.492 3.552-1.476 1.476-2.168 1.476-3.552zm4.053 11.1l-4.603-4.592c-1.339.928-2.832 1.391-4.477 1.391-1.07 0-2.093-.208-3.069-.623-.976-.415-1.818-.976-2.525-1.683-.707-.707-1.268-1.549-1.683-2.525-.415-.976-.623-1.999-.623-3.069 0-1.07.208-2.093.623-3.069.415-.976.976-1.818 1.683-2.525.707-.707 1.549-1.268 2.525-1.683.976-.415 1.999-.623 3.069-.623 1.07 0 2.093.208 3.069.623.976.415 1.818.976 2.525 1.683.707.707 1.268 1.549 1.683 2.525.415.976.623 1.999.623 3.069 0 1.646-.464 3.138-1.391 4.477l4.603 4.603-2.031 2.02z" fill="#1658DA">
#            </path>
#           </svg>
#          </ins>
#         </span>
#        </div>
#        <div class="right">
#         <div class="header__controls">
#          <span class="control is-mobile control_menu control_menu--close js-control_menu_close" onclick="void(0)">
#           <ins>
#           </ins>
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="js-search_mobile_popup not_display is-mobile">
#        <div class="search-form">
#         <form action="//www.hse.ru/en/search/index.html">
#          <div class="search-form__button">
#           <button class="button button_grey ">
#            Search
#           </button>
#          </div>
#          <div class="search-form__input">
#           <input class="input fa-search_input input100 input_mr" name="text" placeholder="Looking for..." type="text"/>
#           <input name="simple" type="hidden" value="1"/>
#           <input name="searchid" type="hidden" value="2284688"/>
#          </div>
#         </form>
#        </div>
#        <div class="popup__block">
#         <a class="link_white" href="//www.hse.ru/en/search/search.html?simple=0&amp;searchid=2284688">
#          Advanced search
#         </a>
#        </div>
#       </div>
#       <div class="header-board__title">
#        <a class="link_white link_no-underline" href="//www.hse.ru/en/">
#         <div class="logo__title">
#          Higher School of Economics
#         </div>
#         <span class="logo__subtitle">
#          National Research University
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="js-mobile_popup__inner fa-sidemenu--primary">
#       <div class="js-mobile_menu_content_wrap">
#        <ul class="main_menu">
#         <li class="js-dropdown main_menu__item main_menu__item--red">
#          <a class="js-dropdown_link" href="https://www.hse.ru/en/info/">
#           About
#          </a>
#          <i class="fa-sidemenu__arr">
#          </i>
#          <div class="main_menu__sub js-dropdown__sub">
#           <ul class="main_menu__sublist">
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/en/figures/">
#              Facts and Figures
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="https://strategy.hse.ru/en/rating/">
#              HSE in Rankings
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://strategy.hse.ru/en/">
#              Development Strategy
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="https://www.hse.ru/en/buildinghse/">
#              HSE Buildings
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="js-dropdown main_menu__item main_menu__item--brown">
#          <a class="js-dropdown_link" href="http://www.hse.ru/en/education/">
#           Programmes &amp; Courses
#          </a>
#         </li>
#         <li class="js-dropdown main_menu__item main_menu__item--green">
#          <a class="js-dropdown_link" href="http://www.hse.ru/admissions">
#           Admissions
#          </a>
#          <i class="fa-sidemenu__arr">
#          </i>
#          <div class="main_menu__sub js-dropdown__sub">
#           <ul class="main_menu__sublist">
#            <li class="main_menu__subitem">
#             <a href="https://www.hse.ru/admissions/preparatory-apply">
#              Preparatory​ Year
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/admissions/undergraduate-apply">
#              Undergraduate Programmes
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/admissions/graduate-apply">
#              Graduate Programmes
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://aspirantura.hse.ru/en/">
#              Doctoral​ Programmes
#             </a>
#            </li>
#            <li class="main_menu__subitem main_menu__subitem--subheader">
#             Short-term programmes
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/international/summer/">
#              Summer University
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/international/semester">
#              Semester in Moscow
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/doingbusiness">
#              Doing Business in Russia - Internship
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/admissions/exchange-apply">
#              Exchange Programmes
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/en/rfl/">
#              Russian Language Training
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/en/sumschool">
#              Summer Schools
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/en/winter/">
#              Winter Schools
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="js-dropdown main_menu__item main_menu__item--violet">
#          <a class="js-dropdown_link" href="http://www.hse.ru/en/science/">
#           Research
#          </a>
#          <i class="fa-sidemenu__arr">
#          </i>
#          <div class="main_menu__sub js-dropdown__sub">
#           <ul class="main_menu__sublist">
#            <li class="main_menu__subitem">
#             <a href="https://www.hse.ru/en/science/about1/">
#              About research at HSE
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://www.hse.ru/interlabs/">
#              International Laboratories
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="https://www.hse.ru/en/science/conferences/">
#              Conferences
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="http://publications.hse.ru/en/">
#              Publications
#             </a>
#            </li>
#            <li class="main_menu__subitem">
#             <a href="https://www.hse.ru/en/science/review/">
#              HSE University Review
#             </a>
#            </li>
#            <li class="main_menu__subitem main_menu__subitem--important">
#             <a class="simple_btn" href="http://iq.hse.ru/en/">
#              IQ.hse.ru
#             </a>
#             <span class="is-block">
#              <a class="link link--important" href="http://iq.hse.ru/en/">
#               Research-based analysis by HSE experts
#              </a>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="js-dropdown main_menu__item main_menu__item--yellow">
#          <a class="js-dropdown_link" href="https://istudents.hse.ru/">
#           International Support
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="main_slider fotorama" data-autoplay="4000" data-click="false" data-height="400px" data-loop="true" data-transitionduration="750" data-width="100%">
#      <div class="main_slider__item interstud" style="background-image: url('//www.hse.ru/pubs/share/direct/201347995');">
#       <h3 class="main_slider__title">
#        <a href="https://www.hse.ru/en/news/admission/222430207.html">
#         International Youth Olympiad for Prospective Students
#        </a>
#       </h3>
#       <div class="main_slider__descr">
#        <p>
#         Your chance to win a full-tuition scholarship for HSE's undergraduate programmes
#        </p>
#       </div>
#      </div>
#      <div class="main_slider__item niwork" style="background-image: url('//www.hse.ru/pubs/share/direct/222901503');">
#       <h3 class="main_slider__title">
#        <a href="https://www.hse.ru/en/news/research/222825675.html">
#         Student Research Paper Competition: Open to Everyone
#        </a>
#       </h3>
#       <div class="main_slider__descr">
#        <p>
#         Deadline: October 15, 2018
#        </p>
#       </div>
#      </div>
#      <div class="main_slider__item day18" style="background-image: url('//www.hse.ru/pubs/share/direct/222562510');">
#       <h3 class="main_slider__title">
#        <a href="https://www.hse.ru/en/day2018/">
#         HSE Day in Gorky park
#        </a>
#       </h3>
#       <div class="main_slider__descr">
#        <p class="day18_logo c">
#         <a class="link_no-underline" href="https://www.hse.ru/en/day2018/">
#          <img alt="" src="/mirror/pubs/share/222186039" style="position: absolute; top: 5px; left: calc(50% - 180px); height: 380px;"/>
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#     <section class="section section--logo">
#      <div class="js-info_box_bg info_box_bg">
#      </div>
#      <div class="info_box">
#       <div class="info_box__inner">
#        <p>
#         Consistently ranked as one of Russia’s top universities, the Higher School of Economics (HSE) is a leader in Russian education and one of the preeminent economics and social sciences universities in Eastern Europe and Eurasia. Having rapidly grown into a well-renowned research university over two decades, HSE sets itself apart with its international presence and cooperation.
#         <strong style="font-size: 0.8em;">
#          <a href="https://www.hse.ru/en/info">
#           MORE ABOUT HSE
#          </a>
#         </strong>
#        </p>
#       </div>
#      </div>
#     </section>
#     <section class="section">
#      <div class="section__header clear">
#       <h2 class="section_title">
#        <a id="news">
#        </a>
#        News
#       </h2>
#       <div class="section__controls">
#        <div class="section_caption">
#         Topics
#        </div>
#        <ul class="s-rubric_list">
#         <li>
#          <a class="link rubric rubric_9 s-rubric" href="/en/news/admission/">
#           <span>
#            Admissions
#           </span>
#           <ins>
#            147
#           </ins>
#          </a>
#         </li>
#         <li>
#          <a class="link rubric rubric_32 s-rubric" href="/en/news/edu/">
#           <span>
#            Education
#           </span>
#           <ins>
#            810
#           </ins>
#          </a>
#         </li>
#         <li>
#          <a class="link rubric rubric_46 s-rubric" href="/en/news/research/">
#           <span>
#            Research&amp;Expertise
#           </span>
#           <ins>
#            1522
#           </ins>
#          </a>
#         </li>
#         <li>
#          <a class="link rubric rubric_4 s-rubric" href="/en/news/society/">
#           <span>
#            Society
#           </span>
#           <ins>
#            349
#           </ins>
#          </a>
#         </li>
#         <li>
#          <a class="link rubric rubric_3 s-rubric" href="/en/news/community/">
#           <span>
#            Community
#           </span>
#           <ins>
#            179
#           </ins>
#          </a>
#         </li>
#         <li>
#          <a class="link rubric rubric_26 s-rubric" href="/en/news/campus/">
#           <span>
#            On Campus
#           </span>
#           <ins>
#            878
#           </ins>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="column column-3">
#       <div class="column__item">
#        <ul class="post">
#         <li class="post__item">
#          <a class="link_no-underline post__img_href" href="/en/news/campus/222966241.html">
#           <img alt="20 Things You Might Not Know About HSE - St. Petersburg" class="post__img" src="/pubs/share/thumb/223030302:c429x230+0+58:r433x232!"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="/en/news/campus/222966241.html">
#            20 Things You Might Not Know About HSE - St. Petersburg
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            Celebrating its 20
#            <sup>
#             th
#            </sup>
#            anniversary this year, HSE’s St Petersburg campus came up with the slogan ‘Time to Make Your Dreams Come True.’
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_26" href="/en/news/campus/">
#            <span>
#             On Campus
#            </span>
#           </a>
#           <a class="tag" href="/en/news/keywords/54787531/" title="HSE campuses">
#            HSE campuses
#           </a>
#           <a class="tag" href="/en/news/tags/petersburg/" title="St. Petersburg">
#            St. Petersburg
#           </a>
#          </div>
#         </li>
#         <li class="post__item">
#          <a class="link_no-underline post__img_href" href="https://iq.hse.ru/en/news/222793842.html">
#           <img alt="Psycholinguists Build Eye-tracking Database on Reading in Russian" class="post__img" src="/pubs/share/thumb/222917884:c433x232+0+0:r433x232!"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="https://iq.hse.ru/en/news/222793842.html">
#            Psycholinguists Build Eye-tracking Database on Reading in Russian
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            Researchers from the Higher School of Economics, St. Petersburg State University, and the University of Potsdam have created the first ever database comprised of eye-tracking data collected during reading in Russian. The results are openly available and can be used not only in linguistics, but also in the diagnosis and correction of speech disorders, for example. The research was published in the journal Behavior Research Methods.
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_46" href="/en/news/research/">
#            <span>
#             Research&amp;Expertise
#            </span>
#           </a>
#           <a class="tag" href="/en/news/tags/iq/" title="IQ">
#            IQ
#           </a>
#           <a class="tag" href="/en/news/keywords/60970386/" title="psychology">
#            psychology
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="column__item">
#        <ul class="post">
#         <li class="post__item">
#          <a class="link_no-underline post__img_href" href="/en/news/research/222910514.html">
#           <img alt="HSE Hosts Consortium of Higher Education Researchers Conference for the First Time" class="post__img" src="/pubs/share/thumb/223002430:c431x231+2+37:r433x232!"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="/en/news/research/222910514.html">
#            HSE Hosts Consortium of Higher Education Researchers Conference for the First Time
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            145 researchers from 30 countries discussed how higher education systems work on global and national levels, and how they are influenced by the processes of differentiation and integration.
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_46" href="/en/news/research/">
#            <span>
#             Research&amp;Expertise
#            </span>
#           </a>
#           <a class="tag" href="/en/news/tags/report/" title="Reporting an event">
#            Reporting an event
#           </a>
#           <a class="tag" href="/en/news/keywords/141325152/" title=" higher education">
#            higher education
#           </a>
#          </div>
#         </li>
#         <li class="post__item">
#          <a class="is-desktop link_no-underline post__img_href" href="https://www.hse.ru/en/success/bebutov/">
#           <img alt="'Now Any Humanities Specialist Is Somewhat of a Designer'" class="post__img" src="/pubs/share/direct/223131142"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="https://www.hse.ru/en/success/bebutov/">
#            'Now Any Humanities Specialist Is Somewhat of a Designer'
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            The world is digitising. This is not a simple process for the media, as ‘ordinary’ reality and digital reality are two different worlds, themselves separate from a magazine. Trifon Bebutov, Esquire Russia’s Digital Editorial Director and a graduate of HSE’s continuing education programme in graphic design, met with Success Builder to talk about what responsibilities his job entails, what exactly ‘paper aesthetics’ means, and how bad packaging can kill amazing content.
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_4" href="/en/news/society/">
#            <span>
#             Society
#            </span>
#           </a>
#           <a class="tag" href="/en/news/tags/alumni/" title="alumni">
#            alumni
#           </a>
#           <a class="tag" href="/en/news/tags/success/" title="success builder">
#            success builder
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="column__item">
#        <ul class="post">
#         <li class="post__item">
#          <a class="is-desktop link_no-underline post__img_href" href="/en/news/research/223024738.html">
#           <img alt="HSE&amp;rsquo;s Institute of Education Collaborates with Global School Laboratory" class="post__img" src="/pubs/share/thumb/223157898:c1126x603+0+72:r433x232!"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="/en/news/research/223024738.html">
#            HSE’s Institute of Education Collaborates with Global School Laboratory
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            The Institute of Education at HSE has signed an agreement outlining collaboration with the online platform, GlobalLab - a community of teachers and students who work on joint research projects over the Internet.
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_46" href="/en/news/research/">
#            <span>
#             Research&amp;Expertise
#            </span>
#           </a>
#           <a class="tag" href="/en/news/tags/online/" title="online education">
#            online education
#           </a>
#           <a class="tag" href="/en/news/keywords/63489055/" title="school education">
#            school education
#           </a>
#          </div>
#         </li>
#         <li class="post__item">
#          <a class="is-desktop link_no-underline post__img_href" href="/en/news/society/222960527.html">
#           <img alt="HSE Launching Student Startup Competition" class="post__img" src="/pubs/share/thumb/223131229:c429x230+4+24:r433x232!"/>
#          </a>
#          <h3 class="post__title ">
#           <a href="/en/news/society/222960527.html">
#            HSE Launching Student Startup Competition
#           </a>
#          </h3>
#          <div class="post__descr">
#           <p>
#            The HSE Business Incubator is announcing the start of a student business project competition called the HSE{Business}Cup-2018, organised with the support of the corporate accelerator MTS StartUp Hub. The students with the best ideas will receive up to 200,000 rubles to make their projects a reality. The teams can also count on additional funds from MTS – a stipend and business grant worth 150,000 rubles.
#           </p>
#          </div>
#          <div class="tag-set">
#           <a class="rubric rubric_4" href="/en/news/society/">
#            <span>
#             Society
#            </span>
#           </a>
#           <a class="tag" href="/en/news/tags/students/" title="students">
#            students
#           </a>
#           <a class="tag" href="/en/news/tags/inv/" title="Invitation to participate">
#            Invitation to participate
#           </a>
#           <a class="tag" href="/en/news/keywords/44000132/" title="competition">
#            competition
#           </a>
#           <a class="tag" href="/en/news/keywords/223008212/" title="entrepreneurship projects">
#            entrepreneurship projects
#           </a>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="section_more">
#       <a href="//www.hse.ru/en/news/">
#        All news
#       </a>
#      </div>
#     </section>
#     <section class="section section--abitur" style="background:url(/pubs/share/direct/182029330) 80% 20% no-repeat, url(...) 0 0 repeat-x;">
#      <div class="section__header clear">
#       <h2 class="section_title section_title--abitur">
#        <a id="abitur">
#        </a>
#        Admissions
#       </h2>
#      </div>
#      <div class="column column-8 owl-social">
#       <div class="column__item">
#        <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions">
#         <img alt="International Admissions" src="/pubs/share/thumb/221401653:c150x150+0+0:r150x150!"/>
#        </a>
#        <a class="from_social__title" href="https://www.hse.ru/admissions">
#         International Admissions
#        </a>
#        <div class="from_social__content">
#         Everything you need to know about HSE’s English-taught programmes
#        </div>
#       </div>
#       <div class="column__item">
#        <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/graduate-apply">
#         <img alt="English-taught Master’s Programmes" src="/pubs/share/thumb/221401660:c150x150+0+0:r150x150!"/>
#        </a>
#        <a class="from_social__title" href="https://www.hse.ru/admissions/graduate-apply">
#         English-taught Master’s Programmes
#        </a>
#        <div class="from_social__content">
#         Choose from more than 20 programmes
#        </div>
#       </div>
#       <div class="column__item">
#        <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/undergraduate-apply">
#         <img alt="English-taught Bachelor’s Programmes" src="/pubs/share/thumb/221401667:c150x150+0+0:r150x150!"/>
#        </a>
#        <a class="from_social__title" href="https://www.hse.ru/admissions/undergraduate-apply">
#         English-taught Bachelor’s Programmes
#        </a>
#        <div class="from_social__content">
#         Earn a double-degree from HSE and University of London in economics or international relations
#        </div>
#       </div>
#       <div class="column__item">
#        <a class="from_social__image from_social__image--abitur" href="https://www.hse.ru/admissions/fees&amp;funding">
#         <img alt="Programme Fees" src="/pubs/share/thumb/221401673:c150x150+0+0:r150x150!"/>
#        </a>
#        <a class="from_social__title" href="https://www.hse.ru/admissions/fees&amp;funding">
#         Programme Fees
#        </a>
#        <div class="from_social__content">
#         Learn about programme costs
#        </div>
#       </div>
#       <div class="column__item">
#        <a class="from_social__image from_social__image--abitur" href="https://istudents.hse.ru/">
#         <img alt="International Student Life" src="/pubs/share/thumb/221401687:c150x150+0+0:r150x150!"/>
#        </a>
#        <a class="from_social__title" href="https://istudents.hse.ru/">
#         International Student Life
#        </a>
#        <div class="from_social__content">
#         Find out what it’s like to study at HSE and live in Moscow
#        </div>
#       </div>
#       <div class="column__item">
# ...
#            The International Data Analysis Olympiad is going. HSE participated in its organization.
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/BgY8d5IAVw6/" rel="nofollow">
#           <img alt="@_dariachaban_" src="/pubs/share/cover/thumb/217260352x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/_dariachaban_/" rel="nofollow">
#           @_dariachaban_
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BgY8d5IAVw6/" rel="nofollow">
#            Thinking about HSE in one of our dorms
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/BgNsDwMAzIb/" rel="nofollow">
#           <img alt="@sima_bright" src="/pubs/share/cover/thumb/217260312x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/sima_bright/" rel="nofollow">
#           @sima_bright
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BgNsDwMAzIb/" rel="nofollow">
#            Spring sky over the HSE building
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/Be2LblbnJtH/" rel="nofollow">
#           <img alt="@vandervetrov/" src="/pubs/share/cover/thumb/215789086x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/vandervetrov/" rel="nofollow">
#           @vandervetrov/
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/Be2LblbnJtH/" rel="nofollow">
#            Rock-noodle in HSE Art and Design School
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/BedjTEHHaKY/" rel="nofollow">
#           <img alt=" @maybe_natasha " src="/pubs/share/cover/thumb/214823046x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/maybe_natasha/" rel="nofollow">
#           @maybe_natasha
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BedjTEHHaKY/" rel="nofollow">
#            Poster at HSE Art and Design School
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/BeOpTNUhJOu/" rel="nofollow">
#           <img alt="@tnkmnsk" src="/pubs/share/cover/thumb/214823847x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/tnkmnsk/" rel="nofollow">
#           @tnkmnsk
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BeOpTNUhJOu/" rel="nofollow">
#            Winter in HSE St. Petersburg
#           </a>
#          </div>
#         </div>
#         <div class="column__item">
#          <div class="from_social__network media-ico-blue media-ico-blue_instagram">
#          </div>
#          <a class="from_social__image" href="https://www.instagram.com/p/BaZZq5OHgiq/?taken-by=margaritavlas" rel="nofollow">
#           <img alt="@margaritavlas" src="/pubs/share/cover/thumb/213942794x135x110"/>
#          </a>
#          <a class="from_social__author" href="https://www.instagram.com/margaritavlas/" rel="nofollow">
#           @margaritavlas
#          </a>
#          <div class="from_social__content">
#           <a class="link link_no-underline link_dark no-visited" href="https://www.instagram.com/p/BaZZq5OHgiq/?taken-by=margaritavlas" rel="nofollow">
#            Melancholy HSE clock
#           </a>
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="section section--contacts">
#        <div class="section__header clear">
#         <h2 class="section_title section_title--light">
#          <a id="contacts">
#          </a>
#          Contacts
#         </h2>
#         <div class="section__controls">
#         </div>
#        </div>
#        <div class="column column-5">
#         <div class="column__item">
#          <p class="b">
#           International Admissions
#          </p>
#          <p>
#           <a href="mailto:inter@hse.ru">
#            inter@hse.ru
#           </a>
#          </p>
#          <p>
#           <a href="http://www.hse.ru/admissions">
#            www.hse.ru/admissions
#           </a>
#          </p>
#          <p>
#           +7 (495) 531-00-59
#          </p>
#          <p>
#          </p>
#          <p>
#           <a href="http://www.hse.ru/en/buildinghse/">
#            Map of HSE Buildings
#           </a>
#          </p>
#         </div>
#         <div class="column__item">
#          <p class="b">
#           International Students Support
#          </p>
#          <p>
#           <a class="link" href="mailto:international.study@hse.ru">
#            international.study@hse.ru
#           </a>
#          </p>
#          <p>
#           <a href="http://istudents.hse.ru/">
#            istudents.hse.ru
#           </a>
#          </p>
#          <p>
#           +7 (495) 772-95-90, ext. 12468
#          </p>
#          <p>
#          </p>
#          <p>
#           <strong>
#            Main campus
#           </strong>
#           : 20 Myasnitskaya Ulitsa
#          </p>
#         </div>
#         <div class="column__item">
#          <p class="b">
#           International Faculty Recruitment
#          </p>
#          <p>
#           <a href="mailto:iri@hse.ru" target="_blank">
#            iri@hse.ru
#           </a>
#          </p>
#          <p>
#           <a href="https://iri.hse.ru/">
#            iri.hse.ru
#           </a>
#          </p>
#          <p>
#           +7 (495) 772-95-90, ext. 11009
#          </p>
#         </div>
#         <div class="column__item">
#          <p class="b">
#           International Faculty Support
#          </p>
#          <p>
#           <a href="mailto:ifaculty.support@hse.ru">
#            ifaculty.support@hse.ru
#           </a>
#          </p>
#          <p>
#           <a href="http://ifaculty.hse.ru/">
#            ifaculty.hse.ru
#           </a>
#          </p>
#          <p>
#           +7 (495) 772-95-90 *12504
#          </p>
#         </div>
#         <div class="column__item">
#          <p class="b">
#           PR Office
#          </p>
#          <p>
#           <a href="mailto:press@hse.ru">
#            press@hse.ru
#           </a>
#          </p>
#          <p>
#           <a href="https://pr.hse.ru/en/">
#            pr.hse.ru/en/
#           </a>
#          </p>
#          <p>
#           +7 495 772 9567
#          </p>
#         </div>
#        </div>
#       </section>
#       <footer class="footer section">
#        <div class="footer__navigation column column-5">
#         <ul class="navigation column__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="https://www.hse.ru/en/info/">
#            About
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://www.hse.ru/en/info/">
#            About
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/figures/">
#            Key Figures &amp; Facts
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/education/faculty/">
#            Faculties &amp; Departments
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/intpartners/">
#            International Partnerships
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/org/persons/">
#            Faculty &amp; Staff
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://www.hse.ru/en/buildinghse/">
#            HSE Buildings
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation column__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="http://www.hse.ru/en/education/">
#            Studies
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/admissions">
#            Admissions
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/education/">
#            Programme Catalogue
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/admissions/undergraduate-apply">
#            Undergraduate
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/admissions/graduate-apply">
#            Graduate
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/admissions/exchange-apply">
#            Exchange Programmes
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/international/summer">
#            Summer University
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/sumschool/">
#            Summer Schools
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/international/semester">
#            Semester in Moscow
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://iiab.hse.ru/en/mib">
#            Business Education
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/doingbusiness">
#            Business Internship
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation column__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="http://www.hse.ru/en/science/">
#            Research
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/interlabs/">
#            International Laboratories
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://www.hse.ru/en/science/centers/">
#            Research Centres
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/org/projects/">
#            Research Projects
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/monitoring/">
#            Monitoring Studies
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/science/conferences">
#            Conferences &amp; Seminars
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://iri.hse.ru/">
#            Academic Jobs
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation column__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="http://www.hse.ru/en/pubs.html">
#            Media &amp; Resources
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://publications.hse.ru/en/">
#            Publications by staff
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://www.hse.ru/en/science/journals">
#            HSE Journals
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://id.hse.ru/en/">
#            Publishing House
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://iq.hse.ru/en/">
#            iq.hse.ru: commentary by HSE experts
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://library.hse.ru/en/">
#            Library
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://sophist.hse.ru/eng/">
#            Economic &amp; Social Data Archive
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://www.youtube.com/playlist?list=PL-U1Z5tJ1i-YhBCL9qUCaTf9cN8TF67VR " rel="nofollow">
#            Video
#           </a>
#          </li>
#         </ul>
#         <ul class="navigation column__item">
#          <li class="navigation__item navigation__item--parent">
#           <a class="navigation__link" href="//www.hse.ru/en/">
#            Useful Links
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://elearning.hse.ru/en/mooc/">
#            Massive Open Online Courses
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="https://www.hse.ru/en/visual/">
#            HSE Site for the Visually Impaired
#           </a>
#          </li>
#          <li class="navigation__item">
#           <a class="navigation__link" href="http://5top100.com/" rel="nofollow">
#            Russian Academic Excellence Project 5-100
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="footer__bottom">
#         <a id="sitemap">
#         </a>
#         <div class="editor">
#          <!--noindex-->
#          <a class="link" href="//www.hse.ru/en/adm/?newportal=1" rel="nofollow">
#           Edit
#          </a>
#          <!--/noindex-->
#         </div>
#         <div class="footer__navigation">
#          <ul class="navigation navigation--horiz footer__copyright">
#           <li class="navigation__item grey">
#            © HSE 1993–2018
#           </li>
#           <li class="navigation__item">
#            <a href="http://www.hse.ru/en/contacts.html">
#             Contacts
#            </a>
#           </li>
#           <li class="navigation__item">
#            <a href="http://www.hse.ru/en/copyright">
#             Copyright
#            </a>
#           </li>
#           <li class="navigation__item">
#            <a href="https://www.hse.ru/en/data_protection_regulation">
#             Privacy Policy
#            </a>
#           </li>
#           <li class="navigation__item">
#            <a href="http://www.hse.ru/en/sitemap.html">
#             Site Map
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="footer__copyright">
#          Webpage design by HSE Design Lab
#         </div>
#        </div>
#       </footer>
#      </div>
#     </section>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# давайте поищем в soup
soup.find_all('ul', attrs={'class':'main_menu'})
# Out:
# [<ul class="main_menu">
#  <li class="js-dropdown main_menu__item main_menu__item--red"><a class="js-dropdown_link" href="https://www.hse.ru/en/info/">About</a>
#  <i class="fa-sidemenu__arr"></i>
#  <div class="main_menu__sub js-dropdown__sub">
#  <ul class="main_menu__sublist">
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/en/figures/">Facts and Figures</a></li>
#  <li class="main_menu__subitem"><a href="https://strategy.hse.ru/en/rating/">HSE in Rankings</a></li>
#  <li class="main_menu__subitem"><a href="http://strategy.hse.ru/en/">Development Strategy</a></li>
#  <li class="main_menu__subitem"><a href="https://www.hse.ru/en/buildinghse/">HSE Buildings</a></li>
#  </ul>
#  </div>
#  </li>
#  <li class="js-dropdown main_menu__item main_menu__item--brown"><a class="js-dropdown_link" href="http://www.hse.ru/en/education/">Programmes &amp; Courses</a>
#  </li>
#  <li class="js-dropdown main_menu__item main_menu__item--green"><a class="js-dropdown_link" href="http://www.hse.ru/admissions">Admissions</a>
#  <i class="fa-sidemenu__arr"></i>
#  <div class="main_menu__sub js-dropdown__sub">
#  <ul class="main_menu__sublist">
#  <li class="main_menu__subitem"><a href="https://www.hse.ru/admissions/preparatory-apply">Preparatory​ Year</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/undergraduate-apply">Undergraduate Programmes</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/graduate-apply">Graduate Programmes</a></li>
#  <li class="main_menu__subitem"><a href="http://aspirantura.hse.ru/en/">Doctoral​ Programmes</a></li>
#  <li class="main_menu__subitem main_menu__subitem--subheader">Short-term programmes</li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/international/summer/">Summer University</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/international/semester">Semester in Moscow</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/doingbusiness">Doing Business in Russia - Internship</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/admissions/exchange-apply">Exchange Programmes</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/en/rfl/">Russian Language Training</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/en/sumschool">Summer Schools</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/en/winter/">Winter Schools</a></li>
#  </ul>
#  </div>
#  </li>
#  <li class="js-dropdown main_menu__item main_menu__item--violet"><a class="js-dropdown_link" href="http://www.hse.ru/en/science/">Research</a>
#  <i class="fa-sidemenu__arr"></i>
#  <div class="main_menu__sub js-dropdown__sub">
#  <ul class="main_menu__sublist">
#  <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/about1/">About research at HSE</a></li>
#  <li class="main_menu__subitem"><a href="http://www.hse.ru/interlabs/">International Laboratories</a></li>
#  <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/conferences/">Conferences</a></li>
#  <li class="main_menu__subitem"><a href="http://publications.hse.ru/en/">Publications</a></li>
#  <li class="main_menu__subitem"><a href="https://www.hse.ru/en/science/review/">HSE University Review</a></li>
#  <li class="main_menu__subitem main_menu__subitem--important">
#  <a class="simple_btn" href="http://iq.hse.ru/en/">IQ.hse.ru</a>
#  <span class="is-block"><a class="link link--important" href="http://iq.hse.ru/en/">Research-based analysis by HSE experts</a></span>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li class="js-dropdown main_menu__item main_menu__item--yellow"><a class="js-dropdown_link" href="https://istudents.hse.ru/">International Support</a>
#  </li>
#  </ul>]

# %%
# и на другом примере
def get_soup(url):
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, 'lxml')
    return soup

url = 'https://www.hse.ru/en/news/'
soup = get_soup(url)

for item in soup.find_all('h2', attrs={'class':'first_child'}):
    url = item.find('a').get('href')
    root = 'https://www.hse.ru'
    if not 'hse.ru' in url:
        url =  root + url
    print(url)
# Out:
# https://www.hse.ru/en/success/bebutov/
# https://www.hse.ru/en/news/research/223024738.html
# https://www.hse.ru/en/news/edu/222999781.html
# https://www.hse.ru/en/news/campus/222966241.html
# https://www.hse.ru/en/news/society/222960527.html
# https://www.hse.ru/en/news/research/222945488.html
# https://iq.hse.ru/en/news/222793842.html
# https://www.hse.ru/en/news/research/222910514.html
# https://www.hse.ru/en/news/edu/222825800.html
# https://www.hse.ru/en/news/research/222825675.html

# %% [markdown]
# ### Поиск в google

# %%
# теперь выведем  кликабельные ссылки
google = 'https://google.com/search?q='
query = 'щшгнпеа'

soup = get_soup(google + query)

# %%
# теперь выведем не сами ссылки, а их TITLE

from IPython.display import HTML, display

# %%
def google(query):
    google = 'http://google.com/search?q=' 

    return

google('hse')

# %% [markdown]
# ### Обход блокировки

# %% [markdown]
# Когда вы слишком подозрительно по мнению владельца сайта себя ведете, вам предлагают разгадать капчу, чтобы подтвердить, что вы человек, а не робот, парсящий данные (наш случай)
# Вы, в данном случае, это ваш IP адрес
# Следовательно, обойти капчу можно двумя способами:
#     - разгадать ее умным алгоритмом (нейронки на изображениях)
#     - сменить айпишник. Именно это происходит, когда вы заходите на запрещенные ресурсы через TOR или пользуетесь телеграмом через VPN. Ваш IP меняется таким образом, будто вы находитесь не в России
#     - использовать sleep(n) для имитации медлительности человека. При этом, n хорошо бы делать рандомным числом в разумных пределах, например от 1 до 4

# %%
# надежно, просто, не быстро

import time
time.sleep(2)

# %% [markdown]
# > Ну что, приступим в сложной части - настройка прокси соединения
# Действуем по инструкции - https://gist.github.com/ifnull/9026823
#
# 1. Cкачиваем privoxy (открываем инстукцию, заходим в настройки компьютера, включаем прокси)
# 2. Cкачиваем tor
# 3. Cоздаем файл config —
# ```
# sudo vi /usr/local/etc/privoxy/config
# ```
# и вставляем туда
# ```
# forward-socks5 / 127.0.0.1:9050 .
# ```
# 4. Cтартуем Privoxy
#    ``` sudo /Applications/Privoxy/stopPrivoxy.sh
#    sudo /Applications/Privoxy/startPrivoxy.sh
#    ```
# 5. Cтартуем Tor ```sudo tor```
#
# Если не работает, попробуйте сменить версию пакетов (но это не точно):
# ```
# pip install pysocks==1.5.6
# pip install requests==2.10.0
# ```

# %% [markdown]
# Проверим
# Создадим пустую сессию

# %%
session = requests.session()
session.proxies = {}

# %% [markdown]
# И узнаем свой IP адрес, обратившись к _httpbin.org_

# %%
r = session.get('http://httpbin.org/ip')
print(r.text)
# Out:
# {
#   "origin": "178.140.23.156"
# }

# %% [markdown]
# Теперь создадим сессию и добавим к ней прокси

# %%
import requests

proxies = {
  "http": "http://127.0.0.1:8118"
}

headers = {
  'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.73.11 (KHTML, like Gecko) Version/7.0.1 Safari/537.73.11'
}

session = requests.session()
r = session.get("http://www.httpbin.org/ip", proxies=proxies, headers=headers)

print(r.text)
# Out:
# {
#   "origin": "185.220.101.27"
# }

# %% [markdown]
# Если ваш IP изменился, поздравляю!
